# %%
import datetime as dt
import glob
from zoneinfo import ZoneInfo

import dill as pk
import numpy as np
import pandas as pd

from sotodlib import core
from sotodlib.tod_ops.flags import get_det_bias_flags

import latcom.utils.net_utils as nu
from latcom.utils.optical_loading import (
    aso_tubes,
    lf_tubes,
    pwv_interp,
    so_nominal_tubes,
    ot_from_ufm,
    ufm_dict,
)
import latcom.utils.yield_utils as yd

import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # ASO Yields

# %%
ctx = core.Context("../ctxs/smurf_det_preproc.yaml")
ufm = "mv24"
band = "090"
ot = ot_from_ufm(ufm)

start = dt.datetime(2026, 6, 1, tzinfo=dt.timezone.utc)
end = dt.datetime(2026, 6, 15, tzinfo=dt.timezone.utc)


obs_list = ctx.obsdb.query(
    f"{end.timestamp()} > timestamp and timestamp > {start.timestamp()} and type=='obs' and subtype=='cmb'"
)


pwv = pwv_interp()

obs_ctx_list = []
for i, obs in enumerate(obs_list):
    cur_ot = str(obs["obs_id"]).split("_")[2][3:]
    obs_id = str(obs["obs_id"])
    if cur_ot in so_nominal_tubes:
        obs_ctx_list.append((obs_id, "../ctxs/preprocess_nominal.yaml"))
    elif cur_ot in aso_tubes:
        obs_ctx_list.append((obs_id, "../ctxs/preprocess_aso.yaml"))
    elif cur_ot in lf_tubes:
        obs_ctx_list.append((obs_id, "../ctxs/preprocess_lf.yaml"))

toby_df = yd.aso_toby_df
pton_df = yd.ptown_df

# %%
for (obs_id, ctx_path) in obs_ctx_list:
    if ot in obs_id:
        print(obs_id)
        ctx = core.Context(ctx_path)
        break
metas = []
for (obs_id, ctx_path) in obs_ctx_list:
    if ot in obs_id:
        print(obs_id)
        try:
            meta = ctx.get_meta(obs_id,dets={"dets:stream_id": "ufm_" + str(ufm), "dets:wafer.bandpass": "f" + str(band),},)
            metas.append(meta)
            
        except:
            continue
# Out:
# obs_1780272166_lati1_111
# obs_1780272166_lati1_111
# obs_1780277753_lati1_111
# obs_1780280079_lati1_111
# obs_1780283695_lati1_111
# obs_1780288319_lati1_111
# obs_1780292198_lati1_111
# obs_1780294596_lati1_111
# obs_1780298186_lati1_111
# obs_1780301792_lati1_111
# obs_1780305397_lati1_111
# obs_1780311994_lati1_111
# obs_1780313876_lati1_111
# obs_1780317481_lati1_111
# obs_1780318535_lati1_111
# obs_1780321271_lati1_111
# obs_1780326201_lati1_111
# obs_1780329308_lati1_111
# obs_1780340802_lati1_111
# obs_1780342116_lati1_111
# obs_1780345719_lati1_111
# obs_1780350037_lati1_111
# obs_1780351524_lati1_111
# obs_1780355124_lati1_111
# obs_1780358719_lati1_111
# obs_1780363838_lati1_111
# obs_1780366899_lati1_111
# obs_1780370494_lati1_111
# obs_1780374105_lati1_111
# obs_1780378361_lati1_111
# obs_1780380248_lati1_111
# obs_1780383837_lati1_111
# obs_1780387438_lati1_111
# obs_1780391037_lati1_111
# obs_1780397417_lati1_111
# obs_1780399657_lati1_111
# obs_1780403247_lati1_111
# obs_1780406843_lati1_111
# obs_1780413278_lati1_111
# obs_1780451622_lati1_111
# obs_1780456046_lati1_111
# obs_1780458286_lati1_111
# obs_1780461908_lati1_111
# obs_1780466516_lati1_111
# obs_1780469105_lati1_111
# obs_1780472711_lati1_111
# obs_1780476309_lati1_111
# obs_1780485794_lati1_111
# obs_1780487542_lati1_111
# obs_1780491170_lati1_111
# obs_1780500461_lati1_111
# obs_1780506305_lati1_111
# obs_1780508759_lati1_111
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/lat-iso/aso/v1/preprocessing/archives_nominal//process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess'}
#
#   request: {'obs:obs_id': 'obs_1780508759_lati1_111', 'dets:stream_id': 'ufm_mv24', 'dets:wafer.bandpass': 'f090'}
# obs_1780512399_lati1_111
# obs_1780516002_lati1_111
# obs_1780519599_lati1_111
# obs_1780521702_lati1_111
# obs_1780523871_lati1_111
# obs_1780527483_lati1_111
# obs_1780534505_lati1_111
# obs_1780547841_lati1_111
# obs_1780548946_lati1_111
# obs_1780552547_lati1_111
# obs_1780556152_lati1_111
# obs_1780559752_lati1_111
# obs_1780564383_lati1_111
# obs_1780566942_lati1_111
# obs_1780570545_lati1_111
# obs_1780577681_lati1_111
# obs_1780581347_lati1_111
# obs_1780584944_lati1_111
# obs_1780593592_lati1_111
# obs_1780618059_lati1_111
# obs_1780621045_lati1_111
# obs_1780634284_lati1_011
# obs_1780638065_lati1_011
# obs_1780641660_lati1_011
# obs_1780645250_lati1_011
# obs_1780649883_lati1_111
# obs_1780652456_lati1_111
# obs_1780656058_lati1_111
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/lat-iso/aso/v1/preprocessing/archives_nominal//process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess'}
#
#   request: {'obs:obs_id': 'obs_1780656058_lati1_111', 'dets:stream_id': 'ufm_mv24', 'dets:wafer.bandpass': 'f090'}
# obs_1780683452_lati1_011
# obs_1780687240_lati1_011
# obs_1780692145_lati1_011
# obs_1780693989_lati1_011
# obs_1780697561_lati1_011
# obs_1780701150_lati1_011
# obs_1780706800_lati1_011
# obs_1780710765_lati1_011
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/lat-iso/aso/v1/preprocessing/archives_nominal//process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess'}
#
#   request: {'obs:obs_id': 'obs_1780714397_lati1_011', 'dets:stream_id': 'ufm_mv24', 'dets:wafer.bandpass': 'f090'}
# obs_1780714397_lati1_011
# obs_1780715327_lati1_011
# obs_1780718217_lati1_011
# obs_1780722831_lati1_011
# obs_1780725417_lati1_011
# obs_1780729027_lati1_011
# obs_1780732619_lati1_011
# obs_1780736220_lati1_011
# obs_1780740829_lati1_011
# obs_1780743426_lati1_011
# obs_1780747710_lati1_011
# obs_1780750417_lati1_011
# obs_1780754046_lati1_011
# obs_1780758660_lati1_011
# obs_1780761880_lati1_011
# obs_1780765685_lati1_011
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/lat-iso/aso/v1/preprocessing/archives_nominal//process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess'}
#
#   request: {'obs:obs_id': 'obs_1780765685_lati1_011', 'dets:stream_id': 'ufm_mv24', 'dets:wafer.bandpass': 'f090'}
#
#
# WARNING: sotodlib.core.metadata.loader: All detectors have been eliminated from processing.
# WARNING: sotodlib.core.metadata.loader:   dets:*: {'stream_id': 'ufm_mv24', 'wafer.bandpass': 'f090'}
# WARNING: sotodlib.core.metadata.loader:   free_tags: []
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/metadata/lat/manifests//det_match/lat_det_match_260416m/assignment_local.sqlite', 'label': 'assignment', 'det_info': True, 'on_missing': 'trim'}
#
#   request: {'obs:obs_id': 'obs_1780774466_lati1_001', 'dets:stream_id': 'ufm_mv24', 'dets:wafer.bandpass': 'f090'}
#
#
# WARNING: sotodlib.core.metadata.loader: All detectors have been eliminated from processing.
# WARNING: sotodlib.core.metadata.loader:   dets:*: {'stream_id': 'ufm_mv24', 'wafer.bandpass': 'f090'}
# WARNING: sotodlib.core.metadata.loader:   free_tags: []
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/metadata/lat/manifests//det_match/lat_det_match_260416m/assignment_local.sqlite', 'label': 'assignment', 'det_info': True, 'on_missing': 'trim'}
#
#   request: {'obs:obs_id': 'obs_1780778251_lati1_001', 'dets:stream_id': 'ufm_mv24', 'dets:wafer.bandpass': 'f090'}
#
#
# WARNING: sotodlib.core.metadata.loader: All detectors have been eliminated from processing.
# WARNING: sotodlib.core.metadata.loader:   dets:*: {'stream_id': 'ufm_mv24', 'wafer.bandpass': 'f090'}
# WARNING: sotodlib.core.metadata.loader:   free_tags: []
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/metadata/lat/manifests//det_match/lat_det_match_260416m/assignment_local.sqlite', 'label': 'assignment', 'det_info': True, 'on_missing': 'trim'}
#
#   request: {'obs:obs_id': 'obs_1780781859_lati1_001', 'dets:stream_id': 'ufm_mv24', 'dets:wafer.bandpass': 'f090'}
#
#
# WARNING: sotodlib.core.metadata.loader: All detectors have been eliminated from processing.
# WARNING: sotodlib.core.metadata.loader:   dets:*: {'stream_id': 'ufm_mv24', 'wafer.bandpass': 'f090'}
# WARNING: sotodlib.core.metadata.loader:   free_tags: []
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/metadata/lat/manifests//det_match/lat_det_match_260416m/assignment_local.sqlite', 'label': 'assignment', 'det_info': True, 'on_missing': 'trim'}
#
#   request: {'obs:obs_id': 'obs_1780785457_lati1_001', 'dets:stream_id': 'ufm_mv24', 'dets:wafer.bandpass': 'f090'}
# obs_1780774466_lati1_001
# obs_1780778251_lati1_001
# obs_1780781859_lati1_001
# obs_1780785457_lati1_001
# obs_1780790920_lati1_011
# obs_1780793096_lati1_011
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/lat-iso/aso/v1/preprocessing/archives_nominal//process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess'}
#
#   request: {'obs:obs_id': 'obs_1780796723_lati1_011', 'dets:stream_id': 'ufm_mv24', 'dets:wafer.bandpass': 'f090'}
# obs_1780796723_lati1_011
# obs_1780800313_lati1_011
# obs_1780801564_lati1_011
# obs_1780805787_lati1_011
# obs_1780808371_lati1_011
# obs_1780811985_lati1_011
# obs_1780815575_lati1_011
# obs_1780819183_lati1_011
# obs_1780823785_lati1_011
# obs_1780826380_lati1_011
# obs_1780829975_lati1_011
# obs_1780833579_lati1_011
# obs_1780837176_lati1_011
# obs_1780841785_lati1_011
# obs_1780844375_lati1_011
# obs_1780848305_lati1_011
# obs_1780852086_lati1_011
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/lat-iso/aso/v1/preprocessing/archives_nominal//process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess'}
#
#   request: {'obs:obs_id': 'obs_1780852086_lati1_011', 'dets:stream_id': 'ufm_mv24', 'dets:wafer.bandpass': 'f090'}
# obs_1780856400_lati1_011
# obs_1780860638_lati1_011
# obs_1780864522_lati1_011
# obs_1780866347_lati1_011
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/lat-iso/aso/v1/preprocessing/archives_nominal//process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess'}
#
#   request: {'obs:obs_id': 'obs_1780866347_lati1_011', 'dets:stream_id': 'ufm_mv24', 'dets:wafer.bandpass': 'f090'}
# obs_1780869285_lati1_011
# obs_1780872914_lati1_011
# obs_1780878517_lati1_011
# obs_1780879930_lati1_011
# obs_1780883529_lati1_011
# obs_1780887127_lati1_011
# obs_1780888364_lati1_011
# obs_1780891321_lati1_011
# obs_1780895967_lati1_011
# obs_1780898553_lati1_011
# obs_1780902156_lati1_011
# obs_1780905758_lati1_011
# obs_1780909361_lati1_011
# obs_1780913964_lati1_011
# obs_1780916559_lati1_011
# obs_1780920162_lati1_011
# obs_1780923759_lati1_011
# obs_1780927086_lati1_011
# obs_1780936597_lati1_111
# obs_1780938774_lati1_111
# obs_1780942126_lati1_111
# obs_1780945744_lati1_111
# obs_1780949366_lati1_111
# obs_1780953956_lati1_111
# obs_1780956556_lati1_111
# obs_1780960159_lati1_111
# obs_1780963803_lati1_111
# obs_1780966630_lati1_111
# obs_1780971264_lati1_111
# obs_1780973867_lati1_111
# obs_1780974952_lati1_111
# obs_1780977564_lati1_111
# obs_1780981182_lati1_111
# obs_1780985784_lati1_111
# obs_1780988382_lati1_111
# obs_1780991996_lati1_111
# obs_1780995586_lati1_111
# obs_1780999194_lati1_111
# obs_1781003783_lati1_111
# obs_1781006381_lati1_111
# obs_1781009986_lati1_111
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/lat-iso/aso/v1/preprocessing/archives_nominal//process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess'}
#
#   request: {'obs:obs_id': 'obs_1781009986_lati1_111', 'dets:stream_id': 'ufm_mv24', 'dets:wafer.bandpass': 'f090'}
# obs_1781099561_lati1_111
# obs_1781103489_lati1_111
# obs_1781107578_lati1_111
# obs_1781111289_lati1_111
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/lat-iso/aso/v1/preprocessing/archives_nominal//process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess'}
#
#   request: {'obs:obs_id': 'obs_1781111289_lati1_111', 'dets:stream_id': 'ufm_mv24', 'dets:wafer.bandpass': 'f090'}
# obs_1781188882_lati1_111
# obs_1781202517_lati1_111
# obs_1781203936_lati1_111
# obs_1781207557_lati1_111
# obs_1781212029_lati1_111
# obs_1781214642_lati1_111
# obs_1781219245_lati1_111
# obs_1781221835_lati1_111
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/lat-iso/aso/v1/preprocessing/archives_nominal//process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess'}
#
#   request: {'obs:obs_id': 'obs_1781221835_lati1_111', 'dets:stream_id': 'ufm_mv24', 'dets:wafer.bandpass': 'f090'}
# obs_1781222799_lati1_111
# obs_1781225975_lati1_111
# obs_1781229600_lati1_111
# obs_1781236850_lati1_111
# obs_1781240478_lati1_111
# obs_1781244085_lati1_111
# obs_1781247676_lati1_111
# obs_1781252285_lati1_111
# obs_1781254876_lati1_111
# obs_1781258486_lati1_111
# obs_1781262106_lati1_111
# obs_1781267200_lati1_111
# obs_1781268860_lati1_111
# obs_1781272480_lati1_111
# obs_1781276072_lati1_111
# obs_1781280362_lati1_111
# obs_1781285081_lati1_111
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/lat-iso/aso/v1/preprocessing/archives_nominal//process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess'}
#
#   request: {'obs:obs_id': 'obs_1781285081_lati1_111', 'dets:stream_id': 'ufm_mv24', 'dets:wafer.bandpass': 'f090'}
# obs_1781302718_lati1_111
# obs_1781306427_lati1_111
# obs_1781309504_lati1_111
# obs_1781311667_lati1_111
# obs_1781315281_lati1_111
# obs_1781318881_lati1_111
# obs_1781321079_lati1_111
# obs_1781322891_lati1_111
# obs_1781326504_lati1_111
# obs_1781330103_lati1_111
# obs_1781333700_lati1_111
# obs_1781338305_lati1_111
# obs_1781348225_lati1_111
# obs_1781351918_lati1_111
# obs_1781366617_lati1_111
# obs_1781370787_lati1_111
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/lat-iso/aso/v1/preprocessing/archives_nominal//process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess'}
#
#   request: {'obs:obs_id': 'obs_1781370787_lati1_111', 'dets:stream_id': 'ufm_mv24', 'dets:wafer.bandpass': 'f090'}
# obs_1781379522_lati1_111
# obs_1781382792_lati1_111
# obs_1781384824_lati1_111
# obs_1781386936_lati1_111
# obs_1781390531_lati1_111
# obs_1781394136_lati1_111
# obs_1781397371_lati1_111
# obs_1781401154_lati1_111
# obs_1781404747_lati1_111
# obs_1781407251_lati1_111
# obs_1781410054_lati1_111
# obs_1781414688_lati1_111
# obs_1781417247_lati1_111
# obs_1781420850_lati1_111
# obs_1781424457_lati1_111
# obs_1781432141_lati1_111
# obs_1781435359_lati1_111
# obs_1781454538_lati1_111
# obs_1781457499_lati1_111
# obs_1781459631_lati1_111
# obs_1781463233_lati1_111
# obs_1781469822_lati1_111
# obs_1781473429_lati1_111
# obs_1781477032_lati1_111

# %%
obs_ids = []
times = []
bias_yields = []
noise_yields = []
pwvs = []

for i in range(len(metas)):
    meta = metas[i]
    obs_id = meta.obs_info.obs_id
    if "mv" in ufm:
        if band == "090":
            ufm_band = 1
        elif band == "150":
            ufm_band = 2
    if "uv" in ufm:
        if band == "220":
            ufm_band = 1
        elif band == "280":
            ufm_band = 2
    flags = get_det_bias_flags(meta).det_bias_flags
    meta.restrict("dets", ~core.flagman.has_any_cuts(flags))
    wafer_flag = np.array([ufm in _ufm for _ufm in meta.det_info.stream_id])
    
    if len(wafer_flag) == 0:
        print(f"No det_info for obs {obs_id}")

    obs_ids.append(obs_id.split("_")[1])
    print(obs_ids[i])
    times.append(dt.datetime.fromtimestamp(int(obs_id.split("_")[1])))
    bias_yield = meta.shape[0]/860
    bias_yields.append(bias_yield)
        
    print("Number of dets after get_bias_flags: ", bias_yield*860, " current yield ", bias_yield)
    bp = (meta.det_cal.bg % 4) // 2
    
    if ufm_band == 1:
        net_flag = wafer_flag * (bp == 0)
    elif ufm_band == 2:
        net_flag = wafer_flag * (bp == 1)
    
    raw_cal = np.nanmedian(meta.abscal.raw_abscal_rj[net_flag])
    if "noise" in meta.preprocess:
        wnoise = meta.preprocess.noise.white_noise[net_flag]
    elif "noiseT" in meta.preprocess:
        wnoise = meta.preprocess.noiseT.white_noise[net_flag]
    else:
        print(f"Error: no valid noise key in {meta.preprocess.keys()}")
    ndet = len(np.where(wnoise != 0)[0])
    noise_yield = ndet/860
    noise_yields.append(noise_yield)
    print("Number of dets with noise estimate: ", noise_yield*860, " current yield ", noise_yield)
    pwvs.append(pwv((obs_id.split("_")[1])))
# Out:
# 1780272166
# Number of dets after get_bias_flags:  753.0  current yield  0.8755813953488372
# Number of dets with noise estimate:  713.0  current yield  0.8290697674418605
# 1780277753
# Number of dets after get_bias_flags:  757.0  current yield  0.8802325581395349
# Number of dets with noise estimate:  722.0  current yield  0.8395348837209302
# 1780280079
# Number of dets after get_bias_flags:  758.0  current yield  0.8813953488372093
# Number of dets with noise estimate:  722.0  current yield  0.8395348837209302
# 1780283695
# Number of dets after get_bias_flags:  756.0  current yield  0.8790697674418605
# Number of dets with noise estimate:  720.0  current yield  0.8372093023255814
# 1780288319
# Number of dets after get_bias_flags:  748.0  current yield  0.8697674418604651
# Number of dets with noise estimate:  703.0  current yield  0.8174418604651162
# 1780292198
# Number of dets after get_bias_flags:  751.0  current yield  0.8732558139534884
# Number of dets with noise estimate:  708.0  current yield  0.8232558139534883
# 1780294596
# Number of dets after get_bias_flags:  608.0  current yield  0.7069767441860465
# Number of dets with noise estimate:  576.0  current yield  0.6697674418604651
# 1780298186
# Number of dets after get_bias_flags:  758.0  current yield  0.8813953488372093
# Number of dets with noise estimate:  722.0  current yield  0.8395348837209302
# 1780301792
# Number of dets after get_bias_flags:  759.0  current yield  0.8825581395348837
# Number of dets with noise estimate:  722.0  current yield  0.8395348837209302
# 1780305397
# Number of dets after get_bias_flags:  759.0  current yield  0.8825581395348837
# Number of dets with noise estimate:  720.0  current yield  0.8372093023255814
# 1780311994
# Number of dets after get_bias_flags:  758.0  current yield  0.8813953488372093
# Number of dets with noise estimate:  722.0  current yield  0.8395348837209302
# 1780313876
# Number of dets after get_bias_flags:  758.0  current yield  0.8813953488372093
# Number of dets with noise estimate:  721.0  current yield  0.8383720930232558
# 1780317481
# Number of dets after get_bias_flags:  758.0  current yield  0.8813953488372093
# Number of dets with noise estimate:  707.0  current yield  0.8220930232558139
# 1780318535
# Number of dets after get_bias_flags:  758.0  current yield  0.8813953488372093
# Number of dets with noise estimate:  712.0  current yield  0.827906976744186
# 1780321271
# Number of dets after get_bias_flags:  758.0  current yield  0.8813953488372093
# Number of dets with noise estimate:  723.0  current yield  0.8406976744186047
# 1780326201
# Number of dets after get_bias_flags:  758.0  current yield  0.8813953488372093
# Number of dets with noise estimate:  719.0  current yield  0.836046511627907
# 1780329308
# Number of dets after get_bias_flags:  760.0  current yield  0.8837209302325582
# Number of dets with noise estimate:  723.0  current yield  0.8406976744186047
# 1780340802
# Number of dets after get_bias_flags:  766.0  current yield  0.8906976744186047
# Number of dets with noise estimate:  728.0  current yield  0.8465116279069768
# 1780342116
# Number of dets after get_bias_flags:  766.0  current yield  0.8906976744186047
# Number of dets with noise estimate:  641.0  current yield  0.7453488372093023
# 1780345719
# Number of dets after get_bias_flags:  768.0  current yield  0.8930232558139535
# Number of dets with noise estimate:  727.0  current yield  0.8453488372093023
# 1780350037
# Number of dets after get_bias_flags:  759.0  current yield  0.8825581395348837
# Number of dets with noise estimate:  720.0  current yield  0.8372093023255814
# 1780351524
# Number of dets after get_bias_flags:  761.0  current yield  0.8848837209302326
# Number of dets with noise estimate:  721.0  current yield  0.8383720930232558
# 1780355124
# Number of dets after get_bias_flags:  762.0  current yield  0.8860465116279069
# Number of dets with noise estimate:  722.0  current yield  0.8395348837209302
# 1780358719
# Number of dets after get_bias_flags:  760.0  current yield  0.8837209302325582
# Number of dets with noise estimate:  721.0  current yield  0.8383720930232558
# 1780363838
# Number of dets after get_bias_flags:  762.0  current yield  0.8860465116279069
# Number of dets with noise estimate:  724.0  current yield  0.8418604651162791
# 1780366899
# Number of dets after get_bias_flags:  770.0  current yield  0.8953488372093024
# Number of dets with noise estimate:  730.0  current yield  0.8488372093023255
# 1780370494
# Number of dets after get_bias_flags:  769.0  current yield  0.8941860465116279
# Number of dets with noise estimate:  729.0  current yield  0.8476744186046512
# 1780374105
# Number of dets after get_bias_flags:  770.0  current yield  0.8953488372093024
# Number of dets with noise estimate:  730.0  current yield  0.8488372093023255
# 1780378361
# Number of dets after get_bias_flags:  635.0  current yield  0.7383720930232558
# Number of dets with noise estimate:  603.0  current yield  0.7011627906976744
# 1780380248
# Number of dets after get_bias_flags:  766.0  current yield  0.8906976744186047
# Number of dets with noise estimate:  725.0  current yield  0.8430232558139535
# 1780383837
# Number of dets after get_bias_flags:  767.0  current yield  0.891860465116279
# Number of dets with noise estimate:  726.0  current yield  0.8441860465116279
# 1780387438
# Number of dets after get_bias_flags:  767.0  current yield  0.891860465116279
# Number of dets with noise estimate:  729.0  current yield  0.8476744186046512
# 1780391037
# Number of dets after get_bias_flags:  767.0  current yield  0.891860465116279
# Number of dets with noise estimate:  727.0  current yield  0.8453488372093023
# 1780397417
# Number of dets after get_bias_flags:  770.0  current yield  0.8953488372093024
# Number of dets with noise estimate:  723.0  current yield  0.8406976744186047
# 1780399657
# Number of dets after get_bias_flags:  770.0  current yield  0.8953488372093024
# Number of dets with noise estimate:  727.0  current yield  0.8453488372093023
# 1780403247
# Number of dets after get_bias_flags:  768.0  current yield  0.8930232558139535
# Number of dets with noise estimate:  718.0  current yield  0.8348837209302326
# 1780406843
# Number of dets after get_bias_flags:  769.0  current yield  0.8941860465116279
# Number of dets with noise estimate:  726.0  current yield  0.8441860465116279
# 1780413278
# Number of dets after get_bias_flags:  770.0  current yield  0.8953488372093024
# Number of dets with noise estimate:  730.0  current yield  0.8488372093023255
# 1780451622
# Number of dets after get_bias_flags:  762.0  current yield  0.8860465116279069
# Number of dets with noise estimate:  723.0  current yield  0.8406976744186047
# 1780456046
# Number of dets after get_bias_flags:  767.0  current yield  0.891860465116279
# Number of dets with noise estimate:  728.0  current yield  0.8465116279069768
# 1780458286
# Number of dets after get_bias_flags:  766.0  current yield  0.8906976744186047
# Number of dets with noise estimate:  723.0  current yield  0.8406976744186047
# 1780461908
# Number of dets after get_bias_flags:  766.0  current yield  0.8906976744186047
# Number of dets with noise estimate:  723.0  current yield  0.8406976744186047
# 1780466516
# Number of dets after get_bias_flags:  758.0  current yield  0.8813953488372093
# Number of dets with noise estimate:  704.0  current yield  0.8186046511627907
# 1780469105
# Number of dets after get_bias_flags:  765.0  current yield  0.8895348837209303
# Number of dets with noise estimate:  716.0  current yield  0.8325581395348837
# 1780472711
# Number of dets after get_bias_flags:  761.0  current yield  0.8848837209302326
# Number of dets with noise estimate:  723.0  current yield  0.8406976744186047
# 1780476309
# Number of dets after get_bias_flags:  763.0  current yield  0.8872093023255814
# Number of dets with noise estimate:  715.0  current yield  0.8313953488372093
# 1780485794
# Number of dets after get_bias_flags:  752.0  current yield  0.8744186046511628
# Number of dets with noise estimate:  703.0  current yield  0.8174418604651162
# 1780487542
# Number of dets after get_bias_flags:  761.0  current yield  0.8848837209302326
# Number of dets with noise estimate:  723.0  current yield  0.8406976744186047
# 1780491170
# Number of dets after get_bias_flags:  759.0  current yield  0.8825581395348837
# Number of dets with noise estimate:  716.0  current yield  0.8325581395348837
# 1780500461
# Number of dets after get_bias_flags:  650.0  current yield  0.7558139534883721
# Number of dets with noise estimate:  367.0  current yield  0.42674418604651165
# 1780506305
# Number of dets after get_bias_flags:  758.0  current yield  0.8813953488372093
# Number of dets with noise estimate:  722.0  current yield  0.8395348837209302
# 1780512399
# Number of dets after get_bias_flags:  757.0  current yield  0.8802325581395349
# Number of dets with noise estimate:  724.0  current yield  0.8418604651162791
# 1780516002
# Number of dets after get_bias_flags:  757.0  current yield  0.8802325581395349
# Number of dets with noise estimate:  723.0  current yield  0.8406976744186047
# 1780519599
# Number of dets after get_bias_flags:  756.0  current yield  0.8790697674418605
# Number of dets with noise estimate:  724.0  current yield  0.8418604651162791
# 1780521702
# Number of dets after get_bias_flags:  750.0  current yield  0.872093023255814
# Number of dets with noise estimate:  712.0  current yield  0.827906976744186
# 1780523871
# Number of dets after get_bias_flags:  752.0  current yield  0.8744186046511628
# Number of dets with noise estimate:  717.0  current yield  0.8337209302325581
# 1780527483
# Number of dets after get_bias_flags:  751.0  current yield  0.8732558139534884
# Number of dets with noise estimate:  714.0  current yield  0.8302325581395349
# 1780534505
# Number of dets after get_bias_flags:  739.0  current yield  0.8593023255813953
# Number of dets with noise estimate:  702.0  current yield  0.8162790697674419
# 1780547841
# Number of dets after get_bias_flags:  734.0  current yield  0.8534883720930233
# Number of dets with noise estimate:  323.0  current yield  0.3755813953488372
# 1780548946
# Number of dets after get_bias_flags:  743.0  current yield  0.8639534883720931
# Number of dets with noise estimate:  703.0  current yield  0.8174418604651162
# 1780552547
# Number of dets after get_bias_flags:  742.0  current yield  0.8627906976744186
# Number of dets with noise estimate:  708.0  current yield  0.8232558139534883
# 1780556152
# Number of dets after get_bias_flags:  742.0  current yield  0.8627906976744186
# Number of dets with noise estimate:  710.0  current yield  0.8255813953488372
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[124], line 20
#      18     elif band == "280":
#      19         ufm_band = 2
# ---> 20 flags = get_det_bias_flags(meta).det_bias_flags
#      21 meta.restrict("dets", ~core.flagman.has_any_cuts(flags))
#      22 wafer_flag = np.array([ufm in _ufm for _ufm in meta.det_info.stream_id])
#
# File /global/u2/j/jorlo/dev/sotodlib/sotodlib/tod_ops/flags.py:101, in get_det_bias_flags(aman, detcal, rfrac_range, psat_range, rn_range, si_range, phase_to_pW, merge, overwrite, name, full_output)
#      98     mskexp = RangesMatrix([Ranges.ones_like(x) if Y
#      99                         else Ranges.zeros_like(x) for Y in msk])
#     100     msk_aman = core.AxisManager(aman.dets, aman.samps)
# --> 101     msk_aman.wrap(name, mskexp, [(0, 'dets'), (1, 'samps')])
#     102 else:
#     103     mskexp = msk
#
# File /global/u2/j/jorlo/dev/sotodlib/sotodlib/core/axisman.py:702, in AxisManager.wrap(self, name, data, axis_map, overwrite, restrict_in_place)
#     699         raise ValueError("Axis assignment refers to unknown "
#     700                          "axis '%s'." % axis)
#     701     axis = self._axes[axis]
# --> 702 axis = axis.resolve(data, index)
#     703 helper._axes[axis.name] = axis
#     704 assign[index] = axis.name
#
# File /global/u2/j/jorlo/dev/sotodlib/sotodlib/core/axisman.py:270, in LabelAxis.resolve(self, src, axis_index)
#     267 if self.count is None:
#     268     raise RuntimeError(
#     269         'LabelAxis cannot be naively promoted from data.')
# --> 270 return super().resolve(src, axis_index)
#
# File /global/u2/j/jorlo/dev/sotodlib/sotodlib/core/axisman.py:68, in AxisInterface.resolve(self, src, axis_index)
#      66 ref_count = src.shape[axis_index]
#      67 if self.count != ref_count:
# ---> 68     raise ValueError(
#      69         "Dimension %i of data is incompatible with axis %s" %
#      70         (axis_index, repr(self)))
#      71 return self
#
# ValueError: Dimension 0 of data is incompatible with axis LabelAxis(794:np.str_('sch_ufm_mv24_1779912861_0_006'),np.str_('sch_ufm_mv24_1779912861_0_008'),np.str_('sch_ufm_mv24_1779912861_0_011'),...,np.str_('sch_ufm_mv24_1779913758_6_499'),np.str_('sch_ufm_mv24_1779913758_6_500'),np.str_('sch_ufm_mv24_1779913758_6_501'),np.str_('sch_ufm_mv24_1779913758_6_504'))

# %%
import matplotlib.dates as mdates
fig, ax = plt.subplots()
noise = ax.plot(times, noise_yields, label="Noise yields")
bias = ax.plot(times, bias_yields, label="Bias yields")

ax2 = ax.twinx()  
pw = ax2.plot(times, pwvs, label="PWV", c="black", alpha = 1, linestyle="--")

ax.set_xlabel("Time")
ax.set_ylabel("Yield")
ax.set_ylim(0, 1)
ax2.set_ylim(0,2)
ax2.set_ylabel("PWV")

ax.axhline(pton_df.loc[pton_df.labels==f"{band}_{ufm}", "yields"].to_numpy(), label="PTon")

plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=2))
plt.gcf().autofmt_xdate()

lns = noise+bias+pw
labs = [l.get_label() for l in lns]
ax.legend(lns, labs)
plt.title(f"Yield for UFM {ufm} band {band}")
plt.savefig(f"../plts/yields/yield_{ufm}_{band}.pdf", dpi=600)
plt.savefig(f"../plts/yields/yield_{ufm}_{band}.png", dpi=600)

plt.show()

# %% [markdown]
# # SO Nominal Yields

# %%
start = dt.datetime(2025, 10, 1, tzinfo=dt.timezone.utc)
end = dt.datetime(2025, 10, 15, tzinfo=dt.timezone.utc)


obs_list = ctx.obsdb.query(
    f"{end.timestamp()} > timestamp and timestamp > {start.timestamp()} and type=='obs' and subtype=='cmb'"
)

obs_ids_list = []
for i, obs in enumerate(obs_list):
    obs_ids_list.append(str(obs["obs_id"]))

# %%
old_ctx = core.Context("../ctxs/old_smurf_det_preproc.yaml")
metas = []
for obs_id in obs_ids_list:
    if ot in obs_id:
        print(obs_id)
        try:
            meta = old_ctx.get_meta(obs_id,dets={"dets:stream_id": "ufm_" + str(ufm), "dets:wafer.bandpass": "f" + str(band),},)
            metas.append(meta)
            
        except:
            continue

# %%
obs_ids = []
times = []
bias_yields = []
noise_yields = []
pwvs = []

for i in range(len(metas)):
    meta = metas[i]
    obs_id = meta.obs_info.obs_id
    if "mv" in ufm:
        if band == "090":
            ufm_band = 1
        elif band == "150":
            ufm_band = 2
    if "uv" in ufm:
        if band == "220":
            ufm_band = 1
        elif band == "280":
            ufm_band = 2
    flags = get_det_bias_flags(meta).det_bias_flags
    meta.restrict("dets", ~core.flagman.has_any_cuts(flags))
    wafer_flag = np.array([ufm in _ufm for _ufm in meta.det_info.stream_id])
    
    if len(wafer_flag) == 0:
        print(f"No det_info for obs {obs_id}")

    obs_ids.append(obs_id.split("_")[1])
    print(obs_ids[i])
    times.append(dt.datetime.fromtimestamp(int(obs_id.split("_")[1])))
    bias_yield = meta.shape[0]/860
    bias_yields.append(bias_yield)
        
    print("Number of dets after get_bias_flags: ", bias_yield*860, " current yield ", bias_yield)
    bp = (meta.det_cal.bg % 4) // 2
    
    if ufm_band == 1:
        net_flag = wafer_flag * (bp == 0)
    elif ufm_band == 2:
        net_flag = wafer_flag * (bp == 1)
    
    raw_cal = np.nanmedian(meta.abscal.raw_abscal_rj[net_flag])
    if "noise" in meta.preprocess:
        wnoise = meta.preprocess.noise.white_noise[net_flag]
    elif "noiseT" in meta.preprocess:
        wnoise = meta.preprocess.noiseT.white_noise[net_flag]
    else:
        print(f"Error: no valid noise key in {meta.preprocess.keys()}")
    ndet = len(np.where(wnoise != 0)[0])
    noise_yield = ndet/860
    noise_yields.append(noise_yield)
    print("Number of dets with noise estimate: ", noise_yield*860, " current yield ", noise_yield)
    pwvs.append(pwv((obs_id.split("_")[1])))

# %%
import matplotlib.dates as mdates
fig, ax = plt.subplots()
noise = ax.plot(times, noise_yields, label="Noise yields")
bias = ax.plot(times, bias_yields, label="Bias yields")

ax2 = ax.twinx()  
pw = ax2.plot(times, pwvs, label="PWV", c="black", alpha = 1, linestyle="--")

ax.set_xlabel("Time")
ax.set_ylabel("Yield")
ax.set_ylim(0, 1)
ax2.set_ylim(0,2)
ax2.set_ylabel("PWV")

ax.axhline(pton_df.loc[pton_df.labels==f"{band}_{ufm}", "yields"].to_numpy(), label="PTon")

plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=2))
plt.gcf().autofmt_xdate()

lns = noise+bias+pw
labs = [l.get_label() for l in lns]
ax.legend(lns, labs)
plt.title(f"Yield for UFM {ufm} band {band}")
plt.savefig(f"../plts/yields/old_yield_{ufm}_{band}.pdf", dpi=600)
plt.savefig(f"../plts/yields/old_yield_{ufm}_{band}.png", dpi=600)

plt.show()

# %%
import datetime as dt
import glob
from zoneinfo import ZoneInfo

import dill as pk
import numpy as np
import pandas as pd

from sotodlib import core
from sotodlib.tod_ops.flags import get_det_bias_flags

import latcom.utils.net_utils as nu
from latcom.utils.optical_loading import (
    aso_tubes,
    lf_tubes,
    pwv_interp,
    so_nominal_tubes,
    ot_from_ufm,
    ufm_dict,
)
import latcom.utils.yield_utils as yd

import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # ASO Yields

# %%
ctx = core.Context("../ctxs/smurf_det_preproc.yaml")
ufm = "mv49"
band = "090"
ot = ot_from_ufm(ufm)

start = dt.datetime(2026, 6, 1, tzinfo=dt.timezone.utc)
end = dt.datetime(2026, 6, 15, tzinfo=dt.timezone.utc)


obs_list = ctx.obsdb.query(
    f"{end.timestamp()} > timestamp and timestamp > {start.timestamp()} and type=='obs' and subtype=='cmb'"
)


pwv = pwv_interp()

obs_ctx_list = []
for i, obs in enumerate(obs_list):
    cur_ot = str(obs["obs_id"]).split("_")[2][3:]
    obs_id = str(obs["obs_id"])
    if cur_ot in so_nominal_tubes:
        obs_ctx_list.append((obs_id, "../ctxs/preprocess_nominal.yaml"))
    elif cur_ot in aso_tubes:
        obs_ctx_list.append((obs_id, "../ctxs/preprocess_aso.yaml"))
    elif cur_ot in lf_tubes:
        obs_ctx_list.append((obs_id, "../ctxs/preprocess_lf.yaml"))

toby_df = yd.aso_toby_df
pton_df = yd.ptown_df

# %%
for (obs_id, ctx_path) in obs_ctx_list:
    if ot in obs_id:
        print(obs_id)
        ctx = core.Context(ctx_path)
        break
metas = []
for (obs_id, ctx_path) in obs_ctx_list:
    if ot in obs_id:
        print(obs_id)
        try:
            meta = ctx.get_meta(obs_id,dets={"dets:stream_id": "ufm_" + str(ufm), "dets:wafer.bandpass": "f" + str(band),},)
            metas.append(meta)
            
        except:
            continue
# Out:
# obs_1780451618_lati4_111
# obs_1780451618_lati4_111
# obs_1780456042_lati4_111
# obs_1780458280_lati4_111
# obs_1780461905_lati4_111
# obs_1780466512_lati4_111
# obs_1780469106_lati4_111
# obs_1780472708_lati4_111
# obs_1780476312_lati4_111
# obs_1780485790_lati4_111
# obs_1780487541_lati4_111
# obs_1780491164_lati4_111
# obs_1780500457_lati4_111
# obs_1780506303_lati4_111
# obs_1780508760_lati4_111
# obs_1780512397_lati4_111
# obs_1780516000_lati4_111
# obs_1780519592_lati4_111
# obs_1780521698_lati4_111
# obs_1780523868_lati4_111
# obs_1780527481_lati4_111
# obs_1780534505_lati4_111
# obs_1780547839_lati4_111
# obs_1780548942_lati4_111
# obs_1780552546_lati4_111
# obs_1780556149_lati4_111
# obs_1780559751_lati4_111
# obs_1780564381_lati4_111
# obs_1780566939_lati4_111
# obs_1780570543_lati4_111
# obs_1780577678_lati4_111
# obs_1780581344_lati4_111
# obs_1780584941_lati4_111
# obs_1780593590_lati4_111
# obs_1780618059_lati4_111
# obs_1780621047_lati4_111
# obs_1780634280_lati4_111
# obs_1780638066_lati4_111
# obs_1780641656_lati4_111
# obs_1780645255_lati4_111
# obs_1780649881_lati4_111
# obs_1780652450_lati4_111
# obs_1780656056_lati4_111
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/lat-iso/aso/v1/preprocessing/archives_nominal//process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess'}
#
#   request: {'obs:obs_id': 'obs_1780656056_lati4_111', 'dets:stream_id': 'ufm_mv49', 'dets:wafer.bandpass': 'f090'}
# obs_1780683454_lati4_111
# obs_1780687242_lati4_111
# obs_1780692145_lati4_111
# obs_1780693988_lati4_111
# obs_1780697561_lati4_111
# obs_1780701151_lati4_111
# obs_1780706798_lati4_111
# obs_1780710762_lati4_111
# obs_1780714394_lati4_111
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/lat-iso/aso/v1/preprocessing/archives_nominal//process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess'}
#
#   request: {'obs:obs_id': 'obs_1780714394_lati4_111', 'dets:stream_id': 'ufm_mv49', 'dets:wafer.bandpass': 'f090'}
# obs_1780715326_lati4_111
# obs_1780718211_lati4_111
# obs_1780722828_lati4_111
# obs_1780725416_lati4_111
# obs_1780729025_lati4_111
# obs_1780732624_lati4_111
# obs_1780736221_lati4_111
# obs_1780740830_lati4_111
# obs_1780743425_lati4_111
# obs_1780747712_lati4_111
# obs_1780750415_lati4_111
# obs_1780754046_lati4_111
# obs_1780758656_lati4_111
# obs_1780761883_lati4_111
# obs_1780765682_lati4_111
# obs_1780774464_lati4_111
# obs_1780778249_lati4_111
# obs_1780781860_lati4_111
# obs_1780785458_lati4_111
# obs_1780790921_lati4_111
# obs_1780793096_lati4_111
# obs_1780796726_lati4_111
# obs_1780800317_lati4_111
# obs_1780801563_lati4_111
# obs_1780805785_lati4_111
# obs_1780808372_lati4_111
# obs_1780811986_lati4_111
# obs_1780815576_lati4_111
# obs_1780819181_lati4_111
# obs_1780823785_lati4_111
# obs_1780826377_lati4_111
# obs_1780829974_lati4_111
# obs_1780833580_lati4_111
# obs_1780837177_lati4_111
# obs_1780841783_lati4_111
# obs_1780844375_lati4_111
# obs_1780848304_lati4_111
# obs_1780852088_lati4_111
# obs_1780856397_lati4_111
# obs_1780860640_lati4_111
# obs_1780864520_lati4_111
# obs_1780866348_lati4_111
# obs_1780869285_lati4_111
# obs_1780872914_lati4_111
# obs_1780878523_lati4_111
# obs_1780879927_lati4_111
# obs_1780883529_lati4_111
# obs_1780887126_lati4_111
# obs_1780888363_lati4_111
# obs_1780891324_lati4_111
# obs_1780895963_lati4_111
# obs_1780898558_lati4_111
# obs_1780902158_lati4_111
# obs_1780905762_lati4_111
# obs_1780909361_lati4_111
# obs_1780913964_lati4_111
# obs_1780916560_lati4_111
# obs_1780920163_lati4_111
# obs_1780923766_lati4_111
# obs_1780927089_lati4_111
# obs_1780936600_lati4_111
# obs_1780938777_lati4_111
# obs_1780942125_lati4_111
# obs_1780945746_lati4_111
# WARNING: sotodlib.core.metadata.loader: All detectors have been eliminated from processing.
# WARNING: sotodlib.core.metadata.loader:   dets:*: {'stream_id': 'ufm_mv49', 'wafer.bandpass': 'f090'}
# WARNING: sotodlib.core.metadata.loader:   free_tags: []
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/metadata/lat/manifests//det_match/lat_det_match_260416m/assignment_local.sqlite', 'label': 'assignment', 'det_info': True, 'on_missing': 'trim'}
#
#   request: {'obs:obs_id': 'obs_1780949368_lati4_110', 'dets:stream_id': 'ufm_mv49', 'dets:wafer.bandpass': 'f090'}
#
#
# WARNING: sotodlib.core.metadata.loader: All detectors have been eliminated from processing.
# WARNING: sotodlib.core.metadata.loader:   dets:*: {'stream_id': 'ufm_mv49', 'wafer.bandpass': 'f090'}
# WARNING: sotodlib.core.metadata.loader:   free_tags: []
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/metadata/lat/manifests//det_match/lat_det_match_260416m/assignment_local.sqlite', 'label': 'assignment', 'det_info': True, 'on_missing': 'trim'}
#
#   request: {'obs:obs_id': 'obs_1780953955_lati4_110', 'dets:stream_id': 'ufm_mv49', 'dets:wafer.bandpass': 'f090'}
#
#
# WARNING: sotodlib.core.metadata.loader: All detectors have been eliminated from processing.
# WARNING: sotodlib.core.metadata.loader:   dets:*: {'stream_id': 'ufm_mv49', 'wafer.bandpass': 'f090'}
# WARNING: sotodlib.core.metadata.loader:   free_tags: []
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/metadata/lat/manifests//det_match/lat_det_match_260416m/assignment_local.sqlite', 'label': 'assignment', 'det_info': True, 'on_missing': 'trim'}
#
#   request: {'obs:obs_id': 'obs_1780956558_lati4_110', 'dets:stream_id': 'ufm_mv49', 'dets:wafer.bandpass': 'f090'}
# obs_1780949368_lati4_110
# obs_1780953955_lati4_110
# obs_1780956558_lati4_110
# obs_1780960159_lati4_110
# WARNING: sotodlib.core.metadata.loader: All detectors have been eliminated from processing.
# WARNING: sotodlib.core.metadata.loader:   dets:*: {'stream_id': 'ufm_mv49', 'wafer.bandpass': 'f090'}
# WARNING: sotodlib.core.metadata.loader:   free_tags: []
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/metadata/lat/manifests//det_match/lat_det_match_260416m/assignment_local.sqlite', 'label': 'assignment', 'det_info': True, 'on_missing': 'trim'}
#
#   request: {'obs:obs_id': 'obs_1780960159_lati4_110', 'dets:stream_id': 'ufm_mv49', 'dets:wafer.bandpass': 'f090'}
#
#
# WARNING: sotodlib.core.metadata.loader: All detectors have been eliminated from processing.
# WARNING: sotodlib.core.metadata.loader:   dets:*: {'stream_id': 'ufm_mv49', 'wafer.bandpass': 'f090'}
# WARNING: sotodlib.core.metadata.loader:   free_tags: []
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/metadata/lat/manifests//det_match/lat_det_match_260416m/assignment_local.sqlite', 'label': 'assignment', 'det_info': True, 'on_missing': 'trim'}
#
#   request: {'obs:obs_id': 'obs_1780963803_lati4_110', 'dets:stream_id': 'ufm_mv49', 'dets:wafer.bandpass': 'f090'}
#
#
# WARNING: sotodlib.core.metadata.loader: All detectors have been eliminated from processing.
# WARNING: sotodlib.core.metadata.loader:   dets:*: {'stream_id': 'ufm_mv49', 'wafer.bandpass': 'f090'}
# WARNING: sotodlib.core.metadata.loader:   free_tags: []
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/metadata/lat/manifests//det_match/lat_det_match_260416m/assignment_local.sqlite', 'label': 'assignment', 'det_info': True, 'on_missing': 'trim'}
#
#   request: {'obs:obs_id': 'obs_1780966631_lati4_110', 'dets:stream_id': 'ufm_mv49', 'dets:wafer.bandpass': 'f090'}
# obs_1780963803_lati4_110
# obs_1780966631_lati4_110
# obs_1780971266_lati4_111
# obs_1780973866_lati4_111
# obs_1780974955_lati4_111
# obs_1780977565_lati4_111
# obs_1780981181_lati4_111
# obs_1780985784_lati4_111
# obs_1780988387_lati4_111
# obs_1780991994_lati4_111
# obs_1780995585_lati4_111
# obs_1780999194_lati4_111
# obs_1781003784_lati4_111
# obs_1781006380_lati4_111
# obs_1781009977_lati4_111
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/lat-iso/aso/v1/preprocessing/archives_nominal//process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess'}
#
#   request: {'obs:obs_id': 'obs_1781009977_lati4_111', 'dets:stream_id': 'ufm_mv49', 'dets:wafer.bandpass': 'f090'}
# obs_1781099561_lati4_111
# obs_1781103490_lati4_111
# obs_1781107578_lati4_111
# obs_1781111287_lati4_111
# obs_1781188885_lati4_111
# obs_1781202517_lati4_111
# obs_1781203936_lati4_111
# obs_1781207555_lati4_111
# obs_1781212027_lati4_111
# obs_1781214644_lati4_111
# obs_1781219244_lati4_111
# obs_1781221834_lati4_111
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/lat-iso/aso/v1/preprocessing/archives_nominal//process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess'}
#
#   request: {'obs:obs_id': 'obs_1781221834_lati4_111', 'dets:stream_id': 'ufm_mv49', 'dets:wafer.bandpass': 'f090'}
# obs_1781222797_lati4_111
# obs_1781225974_lati4_111
# obs_1781229603_lati4_111
# obs_1781236849_lati4_111
# obs_1781240478_lati4_111
# obs_1781244084_lati4_111
# obs_1781247676_lati4_111
# obs_1781252288_lati4_111
# obs_1781254870_lati4_111
# obs_1781258485_lati4_111
# obs_1781262103_lati4_111
# obs_1781267199_lati4_111
# obs_1781268859_lati4_111
# obs_1781272476_lati4_111
# obs_1781276067_lati4_111
# obs_1781280359_lati4_111
# obs_1781285075_lati4_111
# obs_1781302719_lati4_111
# obs_1781306425_lati4_111
# obs_1781309503_lati4_111
# obs_1781311666_lati4_111
# obs_1781315283_lati4_111
# obs_1781318878_lati4_111
# obs_1781321077_lati4_111
# obs_1781322887_lati4_111
# obs_1781326503_lati4_111
# obs_1781330101_lati4_111
# obs_1781333703_lati4_111
# obs_1781338310_lati4_111
# obs_1781348223_lati4_111
# obs_1781351916_lati4_111
# obs_1781366620_lati4_111
# obs_1781370786_lati4_111
# obs_1781379519_lati4_111
# obs_1781382793_lati4_111
# obs_1781384821_lati4_111
# obs_1781386937_lati4_111
# obs_1781390529_lati4_111
# obs_1781394135_lati4_111
# obs_1781397368_lati4_111
# obs_1781401154_lati4_111
# obs_1781404746_lati4_111
# obs_1781407252_lati4_111
# obs_1781410055_lati4_111
# obs_1781414687_lati4_111
# obs_1781417245_lati4_111
# obs_1781420853_lati4_111
# obs_1781424458_lati4_111
# obs_1781432138_lati4_111
# obs_1781435354_lati4_111
# obs_1781454537_lati4_111
# obs_1781457501_lati4_111
# obs_1781459631_lati4_111
# obs_1781463233_lati4_111
# obs_1781469817_lati4_111
# obs_1781473426_lati4_111
# obs_1781477032_lati4_111

# %%
obs_ids = []
times = []
bias_yields = []
noise_yields = []
pwvs = []

for i in range(len(metas)):
    meta = metas[i]
    obs_id = meta.obs_info.obs_id
    if "mv" in ufm:
        if band == "090":
            ufm_band = 1
        elif band == "150":
            ufm_band = 2
    if "uv" in ufm:
        if band == "220":
            ufm_band = 1
        elif band == "280":
            ufm_band = 2
    flags = get_det_bias_flags(meta).det_bias_flags
    meta.restrict("dets", ~core.flagman.has_any_cuts(flags))
    wafer_flag = np.array([ufm in _ufm for _ufm in meta.det_info.stream_id])
    
    if len(wafer_flag) == 0:
        print(f"No det_info for obs {obs_id}")

    obs_ids.append(obs_id.split("_")[1])
    print(obs_ids[i])
    times.append(dt.datetime.fromtimestamp(int(obs_id.split("_")[1])))
    bias_yield = meta.shape[0]/860
    bias_yields.append(bias_yield)
        
    print("Number of dets after get_bias_flags: ", bias_yield*860, " current yield ", bias_yield)
    bp = (meta.det_cal.bg % 4) // 2
    
    if ufm_band == 1:
        net_flag = wafer_flag * (bp == 0)
    elif ufm_band == 2:
        net_flag = wafer_flag * (bp == 1)
    
    raw_cal = np.nanmedian(meta.abscal.raw_abscal_rj[net_flag])
    if "noise" in meta.preprocess:
        wnoise = meta.preprocess.noise.white_noise[net_flag]
    elif "noiseT" in meta.preprocess:
        wnoise = meta.preprocess.noiseT.white_noise[net_flag]
    else:
        print(f"Error: no valid noise key in {meta.preprocess.keys()}")
    ndet = len(np.where(wnoise != 0)[0])
    noise_yield = ndet/860
    noise_yields.append(noise_yield)
    print("Number of dets with noise estimate: ", noise_yield*860, " current yield ", noise_yield)
    pwvs.append(pwv((obs_id.split("_")[1])))
# Out:
# 1780451618
# Number of dets after get_bias_flags:  266.0  current yield  0.30930232558139537
# Number of dets with noise estimate:  247.0  current yield  0.2872093023255814
# 1780456042
# Number of dets after get_bias_flags:  269.0  current yield  0.3127906976744186
# Number of dets with noise estimate:  250.00000000000003  current yield  0.29069767441860467
# 1780458280
# Number of dets after get_bias_flags:  269.0  current yield  0.3127906976744186
# Number of dets with noise estimate:  250.00000000000003  current yield  0.29069767441860467
# 1780461905
# Number of dets after get_bias_flags:  269.0  current yield  0.3127906976744186
# Number of dets with noise estimate:  250.00000000000003  current yield  0.29069767441860467
# 1780466512
# Number of dets after get_bias_flags:  265.0  current yield  0.3081395348837209
# Number of dets with noise estimate:  245.99999999999997  current yield  0.28604651162790695
# 1780469106
# Number of dets after get_bias_flags:  269.0  current yield  0.3127906976744186
# Number of dets with noise estimate:  249.0  current yield  0.2895348837209302
# 1780472708
# Number of dets after get_bias_flags:  269.0  current yield  0.3127906976744186
# Number of dets with noise estimate:  249.0  current yield  0.2895348837209302
# 1780476312
# Number of dets after get_bias_flags:  269.0  current yield  0.3127906976744186
# Number of dets with noise estimate:  250.00000000000003  current yield  0.29069767441860467
# 1780485790
# Number of dets after get_bias_flags:  262.0  current yield  0.30465116279069765
# Number of dets with noise estimate:  243.0  current yield  0.28255813953488373
# 1780487541
# Number of dets after get_bias_flags:  269.0  current yield  0.3127906976744186
# Number of dets with noise estimate:  250.00000000000003  current yield  0.29069767441860467
# 1780491164
# Number of dets after get_bias_flags:  269.0  current yield  0.3127906976744186
# Number of dets with noise estimate:  250.00000000000003  current yield  0.29069767441860467
# 1780500457
# Number of dets after get_bias_flags:  262.0  current yield  0.30465116279069765
# Number of dets with noise estimate:  243.0  current yield  0.28255813953488373
# 1780506303
# Number of dets after get_bias_flags:  266.0  current yield  0.30930232558139537
# Number of dets with noise estimate:  245.99999999999997  current yield  0.28604651162790695
# 1780508760
# Number of dets after get_bias_flags:  266.0  current yield  0.30930232558139537
# Number of dets with noise estimate:  248.00000000000003  current yield  0.28837209302325584
# 1780512397
# Number of dets after get_bias_flags:  266.0  current yield  0.30930232558139537
# Number of dets with noise estimate:  248.00000000000003  current yield  0.28837209302325584
# 1780516000
# Number of dets after get_bias_flags:  266.0  current yield  0.30930232558139537
# Number of dets with noise estimate:  248.00000000000003  current yield  0.28837209302325584
# 1780519592
# Number of dets after get_bias_flags:  266.0  current yield  0.30930232558139537
# Number of dets with noise estimate:  248.00000000000003  current yield  0.28837209302325584
# 1780521698
# Number of dets after get_bias_flags:  261.0  current yield  0.30348837209302326
# Number of dets with noise estimate:  242.0  current yield  0.2813953488372093
# 1780523868
# Number of dets after get_bias_flags:  268.0  current yield  0.3116279069767442
# Number of dets with noise estimate:  247.0  current yield  0.2872093023255814
# 1780527481
# Number of dets after get_bias_flags:  265.0  current yield  0.3081395348837209
# Number of dets with noise estimate:  243.99999999999997  current yield  0.2837209302325581
# 1780534505
# Number of dets after get_bias_flags:  267.0  current yield  0.31046511627906975
# Number of dets with noise estimate:  248.00000000000003  current yield  0.28837209302325584
# 1780547839
# Number of dets after get_bias_flags:  263.0  current yield  0.3058139534883721
# Number of dets with noise estimate:  133.0  current yield  0.15465116279069768
# 1780548942
# Number of dets after get_bias_flags:  269.0  current yield  0.3127906976744186
# Number of dets with noise estimate:  249.0  current yield  0.2895348837209302
# 1780552546
# Number of dets after get_bias_flags:  270.0  current yield  0.313953488372093
# Number of dets with noise estimate:  249.0  current yield  0.2895348837209302
# 1780556149
# Number of dets after get_bias_flags:  271.0  current yield  0.31511627906976747
# Number of dets with noise estimate:  250.00000000000003  current yield  0.29069767441860467
# 1780559751
# Number of dets after get_bias_flags:  271.0  current yield  0.31511627906976747
# Number of dets with noise estimate:  250.00000000000003  current yield  0.29069767441860467
# 1780564381
# Number of dets after get_bias_flags:  265.0  current yield  0.3081395348837209
# Number of dets with noise estimate:  245.99999999999997  current yield  0.28604651162790695
# 1780566939
# Number of dets after get_bias_flags:  269.0  current yield  0.3127906976744186
# Number of dets with noise estimate:  249.0  current yield  0.2895348837209302
# 1780570543
# Number of dets after get_bias_flags:  267.0  current yield  0.31046511627906975
# Number of dets with noise estimate:  247.0  current yield  0.2872093023255814
# 1780577678
# Number of dets after get_bias_flags:  258.0  current yield  0.3
# Number of dets with noise estimate:  240.0  current yield  0.27906976744186046
# 1780581344
# Number of dets after get_bias_flags:  265.0  current yield  0.3081395348837209
# Number of dets with noise estimate:  248.00000000000003  current yield  0.28837209302325584
# 1780584941
# Number of dets after get_bias_flags:  262.0  current yield  0.30465116279069765
# Number of dets with noise estimate:  245.0  current yield  0.28488372093023256
# 1780593590
# Number of dets after get_bias_flags:  251.0  current yield  0.29186046511627906
# Number of dets with noise estimate:  6.0  current yield  0.0069767441860465115
# 1780618059
# Number of dets after get_bias_flags:  264.0  current yield  0.30697674418604654
# Number of dets with noise estimate:  245.0  current yield  0.28488372093023256
# 1780621047
# Number of dets after get_bias_flags:  271.0  current yield  0.31511627906976747
# Number of dets with noise estimate:  250.00000000000003  current yield  0.29069767441860467
# 1780634280
# Number of dets after get_bias_flags:  268.0  current yield  0.3116279069767442
# Number of dets with noise estimate:  249.0  current yield  0.2895348837209302
# 1780638066
# Number of dets after get_bias_flags:  271.0  current yield  0.31511627906976747
# Number of dets with noise estimate:  251.0  current yield  0.29186046511627906
# 1780641656
# Number of dets after get_bias_flags:  271.0  current yield  0.31511627906976747
# Number of dets with noise estimate:  250.00000000000003  current yield  0.29069767441860467
# 1780645255
# Number of dets after get_bias_flags:  271.0  current yield  0.31511627906976747
# Number of dets with noise estimate:  251.0  current yield  0.29186046511627906
# 1780649881
# Number of dets after get_bias_flags:  269.0  current yield  0.3127906976744186
# Number of dets with noise estimate:  250.00000000000003  current yield  0.29069767441860467
# 1780652450
# Number of dets after get_bias_flags:  271.0  current yield  0.31511627906976747
# Number of dets with noise estimate:  252.0  current yield  0.2930232558139535
# 1780683454
# Number of dets after get_bias_flags:  269.0  current yield  0.3127906976744186
# Number of dets with noise estimate:  250.00000000000003  current yield  0.29069767441860467
# 1780687242
# Number of dets after get_bias_flags:  271.0  current yield  0.31511627906976747
# Number of dets with noise estimate:  251.0  current yield  0.29186046511627906
# 1780692145
# Number of dets after get_bias_flags:  267.0  current yield  0.31046511627906975
# Number of dets with noise estimate:  245.99999999999997  current yield  0.28604651162790695
# 1780693988
# Number of dets after get_bias_flags:  270.0  current yield  0.313953488372093
# Number of dets with noise estimate:  250.00000000000003  current yield  0.29069767441860467
# 1780697561
# Number of dets after get_bias_flags:  270.0  current yield  0.313953488372093
# Number of dets with noise estimate:  250.00000000000003  current yield  0.29069767441860467
# 1780701151
# Number of dets after get_bias_flags:  268.0  current yield  0.3116279069767442
# Number of dets with noise estimate:  248.00000000000003  current yield  0.28837209302325584
# 1780706798
# Number of dets after get_bias_flags:  263.0  current yield  0.3058139534883721
# Number of dets with noise estimate:  243.99999999999997  current yield  0.2837209302325581
# 1780710762
# Number of dets after get_bias_flags:  269.0  current yield  0.3127906976744186
# Number of dets with noise estimate:  250.00000000000003  current yield  0.29069767441860467
# 1780715326
# Number of dets after get_bias_flags:  269.0  current yield  0.3127906976744186
# Number of dets with noise estimate:  249.0  current yield  0.2895348837209302
# 1780718211
# Number of dets after get_bias_flags:  269.0  current yield  0.3127906976744186
# Number of dets with noise estimate:  249.0  current yield  0.2895348837209302
# 1780722828
# Number of dets after get_bias_flags:  263.0  current yield  0.3058139534883721
# Number of dets with noise estimate:  159.0  current yield  0.18488372093023256
# 1780725416
# Number of dets after get_bias_flags:  269.0  current yield  0.3127906976744186
# Number of dets with noise estimate:  250.00000000000003  current yield  0.29069767441860467
# 1780729025
# Number of dets after get_bias_flags:  269.0  current yield  0.3127906976744186
# Number of dets with noise estimate:  250.00000000000003  current yield  0.29069767441860467
# 1780732624
# Number of dets after get_bias_flags:  269.0  current yield  0.3127906976744186
# Number of dets with noise estimate:  249.0  current yield  0.2895348837209302
# 1780736221
# Number of dets after get_bias_flags:  269.0  current yield  0.3127906976744186
# Number of dets with noise estimate:  250.00000000000003  current yield  0.29069767441860467
# 1780740830
# Number of dets after get_bias_flags:  263.0  current yield  0.3058139534883721
# Number of dets with noise estimate:  243.99999999999997  current yield  0.2837209302325581
# 1780743425
# Number of dets after get_bias_flags:  269.0  current yield  0.3127906976744186
# Number of dets with noise estimate:  250.00000000000003  current yield  0.29069767441860467
# 1780747712
# Number of dets after get_bias_flags:  269.0  current yield  0.3127906976744186
# Number of dets with noise estimate:  179.0  current yield  0.20813953488372092
# 1780750415
# Number of dets after get_bias_flags:  269.0  current yield  0.3127906976744186
# Number of dets with noise estimate:  250.00000000000003  current yield  0.29069767441860467
# 1780754046
# Number of dets after get_bias_flags:  269.0  current yield  0.3127906976744186
# Number of dets with noise estimate:  249.0  current yield  0.2895348837209302
# 1780758656
# Number of dets after get_bias_flags:  262.0  current yield  0.30465116279069765
# Number of dets with noise estimate:  242.0  current yield  0.2813953488372093
# 1780761883
# Number of dets after get_bias_flags:  269.0  current yield  0.3127906976744186
# Number of dets with noise estimate:  249.0  current yield  0.2895348837209302
# 1780765682
# Number of dets after get_bias_flags:  269.0  current yield  0.3127906976744186
# Number of dets with noise estimate:  249.0  current yield  0.2895348837209302
# 1780774464
# Number of dets after get_bias_flags:  261.0  current yield  0.30348837209302326
# Number of dets with noise estimate:  242.0  current yield  0.2813953488372093
# 1780778249
# Number of dets after get_bias_flags:  268.0  current yield  0.3116279069767442
# Number of dets with noise estimate:  248.00000000000003  current yield  0.28837209302325584
# 1780781860
# Number of dets after get_bias_flags:  267.0  current yield  0.31046511627906975
# Number of dets with noise estimate:  247.0  current yield  0.2872093023255814
# 1780785458
# Number of dets after get_bias_flags:  264.0  current yield  0.30697674418604654
# Number of dets with noise estimate:  245.0  current yield  0.28488372093023256
# 1780790921
# Number of dets after get_bias_flags:  262.0  current yield  0.30465116279069765
# Number of dets with noise estimate:  242.0  current yield  0.2813953488372093
# 1780793096
# Number of dets after get_bias_flags:  265.0  current yield  0.3081395348837209
# Number of dets with noise estimate:  247.0  current yield  0.2872093023255814
# 1780796726
# Number of dets after get_bias_flags:  265.0  current yield  0.3081395348837209
# Number of dets with noise estimate:  248.00000000000003  current yield  0.28837209302325584
# 1780800317
# Number of dets after get_bias_flags:  265.0  current yield  0.3081395348837209
# Number of dets with noise estimate:  248.00000000000003  current yield  0.28837209302325584
# 1780801563
# Number of dets after get_bias_flags:  265.0  current yield  0.3081395348837209
# Number of dets with noise estimate:  248.00000000000003  current yield  0.28837209302325584
# 1780805785
# Number of dets after get_bias_flags:  260.0  current yield  0.3023255813953488
# Number of dets with noise estimate:  241.00000000000003  current yield  0.2802325581395349
# 1780808372
# Number of dets after get_bias_flags:  269.0  current yield  0.3127906976744186
# Number of dets with noise estimate:  248.00000000000003  current yield  0.28837209302325584
# 1780811986
# Number of dets after get_bias_flags:  267.0  current yield  0.31046511627906975
# Number of dets with noise estimate:  248.00000000000003  current yield  0.28837209302325584
# 1780815576
# Number of dets after get_bias_flags:  267.0  current yield  0.31046511627906975
# Number of dets with noise estimate:  248.00000000000003  current yield  0.28837209302325584
# 1780819181
# Number of dets after get_bias_flags:  267.0  current yield  0.31046511627906975
# Number of dets with noise estimate:  26.0  current yield  0.030232558139534883
# 1780823785
# Number of dets after get_bias_flags:  235.0  current yield  0.27325581395348836
# Number of dets with noise estimate:  216.00000000000003  current yield  0.25116279069767444
# 1780826377
# Number of dets after get_bias_flags:  222.0  current yield  0.25813953488372093
# Number of dets with noise estimate:  203.0  current yield  0.23604651162790696
# 1780829974
# Number of dets after get_bias_flags:  238.0  current yield  0.27674418604651163
# Number of dets with noise estimate:  220.0  current yield  0.2558139534883721
# 1780833580
# Number of dets after get_bias_flags:  266.0  current yield  0.30930232558139537
# Number of dets with noise estimate:  248.00000000000003  current yield  0.28837209302325584
# 1780837177
# Number of dets after get_bias_flags:  267.0  current yield  0.31046511627906975
# Number of dets with noise estimate:  143.0  current yield  0.16627906976744186
# 1780841783
# Number of dets after get_bias_flags:  261.0  current yield  0.30348837209302326
# Number of dets with noise estimate:  224.0  current yield  0.26046511627906976
# 1780844375
# Number of dets after get_bias_flags:  261.0  current yield  0.30348837209302326
# Number of dets with noise estimate:  242.0  current yield  0.2813953488372093
# 1780848304
# Number of dets after get_bias_flags:  261.0  current yield  0.30348837209302326
# Number of dets with noise estimate:  241.00000000000003  current yield  0.2802325581395349
# 1780852088
# Number of dets after get_bias_flags:  269.0  current yield  0.3127906976744186
# Number of dets with noise estimate:  249.0  current yield  0.2895348837209302
# 1780856397
# Number of dets after get_bias_flags:  263.0  current yield  0.3058139534883721
# Number of dets with noise estimate:  243.99999999999997  current yield  0.2837209302325581
# 1780860640
# Number of dets after get_bias_flags:  258.0  current yield  0.3
# Number of dets with noise estimate:  239.00000000000003  current yield  0.2779069767441861
# 1780864520
# Number of dets after get_bias_flags:  264.0  current yield  0.30697674418604654
# Number of dets with noise estimate:  92.0  current yield  0.10697674418604651
# 1780866348
# Number of dets after get_bias_flags:  267.0  current yield  0.31046511627906975
# Number of dets with noise estimate:  245.99999999999997  current yield  0.28604651162790695
# 1780869285
# Number of dets after get_bias_flags:  267.0  current yield  0.31046511627906975
# Number of dets with noise estimate:  245.99999999999997  current yield  0.28604651162790695
# 1780872914
# Number of dets after get_bias_flags:  267.0  current yield  0.31046511627906975
# Number of dets with noise estimate:  245.99999999999997  current yield  0.28604651162790695
# 1780878523
# Number of dets after get_bias_flags:  268.0  current yield  0.3116279069767442
# Number of dets with noise estimate:  249.0  current yield  0.2895348837209302
# 1780879927
# Number of dets after get_bias_flags:  270.0  current yield  0.313953488372093
# Number of dets with noise estimate:  251.0  current yield  0.29186046511627906
# 1780883529
# Number of dets after get_bias_flags:  270.0  current yield  0.313953488372093
# Number of dets with noise estimate:  250.00000000000003  current yield  0.29069767441860467
# 1780887126
# Number of dets after get_bias_flags:  270.0  current yield  0.313953488372093
# Number of dets with noise estimate:  249.0  current yield  0.2895348837209302
# 1780888363
# Number of dets after get_bias_flags:  270.0  current yield  0.313953488372093
# Number of dets with noise estimate:  249.0  current yield  0.2895348837209302
# 1780891324
# Number of dets after get_bias_flags:  270.0  current yield  0.313953488372093
# Number of dets with noise estimate:  248.00000000000003  current yield  0.28837209302325584
# 1780895963
# Number of dets after get_bias_flags:  268.0  current yield  0.3116279069767442
# Number of dets with noise estimate:  249.0  current yield  0.2895348837209302
# 1780898558
# Number of dets after get_bias_flags:  270.0  current yield  0.313953488372093
# Number of dets with noise estimate:  250.00000000000003  current yield  0.29069767441860467
# 1780902158
# Number of dets after get_bias_flags:  270.0  current yield  0.313953488372093
# Number of dets with noise estimate:  250.00000000000003  current yield  0.29069767441860467
# 1780905762
# Number of dets after get_bias_flags:  270.0  current yield  0.313953488372093
# Number of dets with noise estimate:  250.00000000000003  current yield  0.29069767441860467
# 1780909361
# Number of dets after get_bias_flags:  270.0  current yield  0.313953488372093
# Number of dets with noise estimate:  124.00000000000001  current yield  0.14418604651162792
# 1780913964
# Number of dets after get_bias_flags:  268.0  current yield  0.3116279069767442
# Number of dets with noise estimate:  249.0  current yield  0.2895348837209302
# 1780916560
# Number of dets after get_bias_flags:  270.0  current yield  0.313953488372093
# Number of dets with noise estimate:  251.0  current yield  0.29186046511627906
# 1780920163
# Number of dets after get_bias_flags:  270.0  current yield  0.313953488372093
# Number of dets with noise estimate:  249.0  current yield  0.2895348837209302
# 1780923766
# Number of dets after get_bias_flags:  270.0  current yield  0.313953488372093
# Number of dets with noise estimate:  249.0  current yield  0.2895348837209302
# 1780927089
# Number of dets after get_bias_flags:  270.0  current yield  0.313953488372093
# Number of dets with noise estimate:  249.0  current yield  0.2895348837209302
# 1780936600
# Number of dets after get_bias_flags:  269.0  current yield  0.3127906976744186
# Number of dets with noise estimate:  251.0  current yield  0.29186046511627906
# 1780938777
# Number of dets after get_bias_flags:  271.0  current yield  0.31511627906976747
# Number of dets with noise estimate:  251.0  current yield  0.29186046511627906
# 1780942125
# Number of dets after get_bias_flags:  271.0  current yield  0.31511627906976747
# Number of dets with noise estimate:  251.0  current yield  0.29186046511627906
# 1780945746
# Number of dets after get_bias_flags:  270.0  current yield  0.313953488372093
# Number of dets with noise estimate:  250.00000000000003  current yield  0.29069767441860467
# 1780971266
# Number of dets after get_bias_flags:  778.0  current yield  0.9046511627906977
# Number of dets with noise estimate:  732.0  current yield  0.8511627906976744
# 1780973866
# Number of dets after get_bias_flags:  790.0  current yield  0.9186046511627907
# Number of dets with noise estimate:  742.0  current yield  0.8627906976744186
# 1780974955
# Number of dets after get_bias_flags:  790.0  current yield  0.9186046511627907
# Number of dets with noise estimate:  735.0  current yield  0.8546511627906976
# 1780977565
# Number of dets after get_bias_flags:  735.0  current yield  0.8546511627906976
# Number of dets with noise estimate:  688.0  current yield  0.8
# 1780981181
# Number of dets after get_bias_flags:  538.0  current yield  0.6255813953488372
# Number of dets with noise estimate:  491.99999999999994  current yield  0.5720930232558139
# 1780985784
# Number of dets after get_bias_flags:  780.0  current yield  0.9069767441860465
# Number of dets with noise estimate:  735.0  current yield  0.8546511627906976
# 1780988387
# Number of dets after get_bias_flags:  791.0  current yield  0.9197674418604651
# Number of dets with noise estimate:  720.0  current yield  0.8372093023255814
# 1780991994
# Number of dets after get_bias_flags:  53.0  current yield  0.06162790697674419
# Number of dets with noise estimate:  15.0  current yield  0.01744186046511628
# 1780995585
# Number of dets after get_bias_flags:  647.0  current yield  0.7523255813953489
# Number of dets with noise estimate:  601.0  current yield  0.6988372093023256
# 1780999194
# Number of dets after get_bias_flags:  730.0  current yield  0.8488372093023255
# Number of dets with noise estimate:  683.0  current yield  0.7941860465116279
# 1781003784
# Number of dets after get_bias_flags:  226.0  current yield  0.2627906976744186
# Number of dets with noise estimate:  182.0  current yield  0.2116279069767442
# 1781006380
# Number of dets after get_bias_flags:  661.0  current yield  0.7686046511627908
# Number of dets with noise estimate:  6.0  current yield  0.0069767441860465115
# 1781099561
# Number of dets after get_bias_flags:  765.0  current yield  0.8895348837209303
# Number of dets with noise estimate:  367.0  current yield  0.42674418604651165
# 1781103490
# Number of dets after get_bias_flags:  778.0  current yield  0.9046511627906977
# Number of dets with noise estimate:  728.0  current yield  0.8465116279069768
# 1781107578
# Number of dets after get_bias_flags:  770.0  current yield  0.8953488372093024
# Number of dets with noise estimate:  55.0  current yield  0.06395348837209303
# 1781111287
# Number of dets after get_bias_flags:  249.0  current yield  0.2895348837209302
# Number of dets with noise estimate:  1.0  current yield  0.0011627906976744186
# 1781188885
# Number of dets after get_bias_flags:  763.0  current yield  0.8872093023255814
# Number of dets with noise estimate:  726.0  current yield  0.8441860465116279
# 1781202517
# Number of dets after get_bias_flags:  771.0  current yield  0.8965116279069767
# Number of dets with noise estimate:  726.0  current yield  0.8441860465116279
# 1781203936
# Number of dets after get_bias_flags:  771.0  current yield  0.8965116279069767
# Number of dets with noise estimate:  726.0  current yield  0.8441860465116279
# 1781207555
# Number of dets after get_bias_flags:  772.0  current yield  0.8976744186046511
# Number of dets with noise estimate:  724.0  current yield  0.8418604651162791
# 1781212027
# Number of dets after get_bias_flags:  781.0  current yield  0.9081395348837209
# Number of dets with noise estimate:  733.0  current yield  0.8523255813953489
# 1781214644
# Number of dets after get_bias_flags:  777.0  current yield  0.9034883720930232
# Number of dets with noise estimate:  731.0  current yield  0.85
# 1781219244
# Number of dets after get_bias_flags:  769.0  current yield  0.8941860465116279
# Number of dets with noise estimate:  723.0  current yield  0.8406976744186047
# 1781222797
# Number of dets after get_bias_flags:  783.0  current yield  0.9104651162790698
# Number of dets with noise estimate:  728.0  current yield  0.8465116279069768
# 1781225974
# Number of dets after get_bias_flags:  785.0  current yield  0.9127906976744186
# Number of dets with noise estimate:  734.0  current yield  0.8534883720930233
# 1781229603
# Number of dets after get_bias_flags:  785.0  current yield  0.9127906976744186
# Number of dets with noise estimate:  741.0  current yield  0.8616279069767442
# 1781236849
# Number of dets after get_bias_flags:  783.0  current yield  0.9104651162790698
# Number of dets with noise estimate:  736.0  current yield  0.8558139534883721
# 1781240478
# Number of dets after get_bias_flags:  787.0  current yield  0.9151162790697674
# Number of dets with noise estimate:  739.0  current yield  0.8593023255813953
# 1781244084
# Number of dets after get_bias_flags:  784.0  current yield  0.9116279069767442
# Number of dets with noise estimate:  726.0  current yield  0.8441860465116279
# 1781247676
# Number of dets after get_bias_flags:  781.0  current yield  0.9081395348837209
# Number of dets with noise estimate:  731.0  current yield  0.85
# 1781252288
# Number of dets after get_bias_flags:  775.0  current yield  0.9011627906976745
# Number of dets with noise estimate:  728.0  current yield  0.8465116279069768
# 1781254870
# Number of dets after get_bias_flags:  783.0  current yield  0.9104651162790698
# Number of dets with noise estimate:  704.0  current yield  0.8186046511627907
# 1781258485
# Number of dets after get_bias_flags:  781.0  current yield  0.9081395348837209
# Number of dets with noise estimate:  726.0  current yield  0.8441860465116279
# 1781262103
# Number of dets after get_bias_flags:  784.0  current yield  0.9116279069767442
# Number of dets with noise estimate:  731.0  current yield  0.85
# 1781267199
# Number of dets after get_bias_flags:  778.0  current yield  0.9046511627906977
# Number of dets with noise estimate:  734.0  current yield  0.8534883720930233
# 1781268859
# Number of dets after get_bias_flags:  782.0  current yield  0.9093023255813953
# Number of dets with noise estimate:  738.0  current yield  0.858139534883721
# 1781272476
# Number of dets after get_bias_flags:  783.0  current yield  0.9104651162790698
# Number of dets with noise estimate:  734.0  current yield  0.8534883720930233
# 1781276067
# Number of dets after get_bias_flags:  786.0  current yield  0.913953488372093
# Number of dets with noise estimate:  740.0  current yield  0.8604651162790697
# 1781280359
# Number of dets after get_bias_flags:  784.0  current yield  0.9116279069767442
# Number of dets with noise estimate:  718.0  current yield  0.8348837209302326
# 1781285075
# Number of dets after get_bias_flags:  769.0  current yield  0.8941860465116279
# Number of dets with noise estimate:  723.0  current yield  0.8406976744186047
# 1781302719
# Number of dets after get_bias_flags:  777.0  current yield  0.9034883720930232
# Number of dets with noise estimate:  733.0  current yield  0.8523255813953489
# 1781306425
# Number of dets after get_bias_flags:  786.0  current yield  0.913953488372093
# Number of dets with noise estimate:  707.0  current yield  0.8220930232558139
# 1781309503
# Number of dets after get_bias_flags:  788.0  current yield  0.9162790697674419
# Number of dets with noise estimate:  742.0  current yield  0.8627906976744186
# 1781311666
# Number of dets after get_bias_flags:  789.0  current yield  0.9174418604651163
# Number of dets with noise estimate:  744.0  current yield  0.8651162790697674
# 1781315283
# Number of dets after get_bias_flags:  790.0  current yield  0.9186046511627907
# Number of dets with noise estimate:  744.0  current yield  0.8651162790697674
# 1781318878
# Number of dets after get_bias_flags:  791.0  current yield  0.9197674418604651
# Number of dets with noise estimate:  744.0  current yield  0.8651162790697674
# 1781321077
# Number of dets after get_bias_flags:  783.0  current yield  0.9104651162790698
# Number of dets with noise estimate:  739.0  current yield  0.8593023255813953
# 1781322887
# Number of dets after get_bias_flags:  790.0  current yield  0.9186046511627907
# Number of dets with noise estimate:  746.0  current yield  0.8674418604651163
# 1781326503
# Number of dets after get_bias_flags:  791.0  current yield  0.9197674418604651
# Number of dets with noise estimate:  745.0  current yield  0.8662790697674418
# 1781330101
# Number of dets after get_bias_flags:  794.0  current yield  0.9232558139534883
# Number of dets with noise estimate:  748.0  current yield  0.8697674418604651
# 1781333703
# Number of dets after get_bias_flags:  794.0  current yield  0.9232558139534883
# Number of dets with noise estimate:  749.0  current yield  0.8709302325581395
# 1781338310
# Number of dets after get_bias_flags:  783.0  current yield  0.9104651162790698
# Number of dets with noise estimate:  739.0  current yield  0.8593023255813953
# 1781348223
# Number of dets after get_bias_flags:  782.0  current yield  0.9093023255813953
# Number of dets with noise estimate:  737.0  current yield  0.8569767441860465
# 1781351916
# Number of dets after get_bias_flags:  794.0  current yield  0.9232558139534883
# Number of dets with noise estimate:  746.0  current yield  0.8674418604651163
# 1781366620
# Number of dets after get_bias_flags:  776.0  current yield  0.9023255813953488
# Number of dets with noise estimate:  732.0  current yield  0.8511627906976744
# 1781370786
# Number of dets after get_bias_flags:  792.0  current yield  0.9209302325581395
# Number of dets with noise estimate:  664.0  current yield  0.772093023255814
# 1781379519
# Number of dets after get_bias_flags:  778.0  current yield  0.9046511627906977
# Number of dets with noise estimate:  720.0  current yield  0.8372093023255814
# 1781382793
# Number of dets after get_bias_flags:  790.0  current yield  0.9186046511627907
# Number of dets with noise estimate:  697.0  current yield  0.8104651162790698
# 1781384821
# Number of dets after get_bias_flags:  790.0  current yield  0.9186046511627907
# Number of dets with noise estimate:  719.0  current yield  0.836046511627907
# 1781386937
# Number of dets after get_bias_flags:  791.0  current yield  0.9197674418604651
# Number of dets with noise estimate:  740.0  current yield  0.8604651162790697
# 1781390529
# Number of dets after get_bias_flags:  792.0  current yield  0.9209302325581395
# Number of dets with noise estimate:  743.0  current yield  0.8639534883720931
# 1781394135
# Number of dets after get_bias_flags:  792.0  current yield  0.9209302325581395
# Number of dets with noise estimate:  744.0  current yield  0.8651162790697674
# 1781397368
# Number of dets after get_bias_flags:  789.0  current yield  0.9174418604651163
# Number of dets with noise estimate:  737.0  current yield  0.8569767441860465
# 1781401154
# Number of dets after get_bias_flags:  797.0  current yield  0.9267441860465117
# Number of dets with noise estimate:  629.0  current yield  0.7313953488372092
# 1781404746
# Number of dets after get_bias_flags:  797.0  current yield  0.9267441860465117
# Number of dets with noise estimate:  571.0  current yield  0.663953488372093
# 1781407252
# Number of dets after get_bias_flags:  797.0  current yield  0.9267441860465117
# Number of dets with noise estimate:  585.0  current yield  0.6802325581395349
# 1781410055
# Number of dets after get_bias_flags:  797.0  current yield  0.9267441860465117
# Number of dets with noise estimate:  601.0  current yield  0.6988372093023256
# 1781414687
# Number of dets after get_bias_flags:  789.0  current yield  0.9174418604651163
# Number of dets with noise estimate:  732.0  current yield  0.8511627906976744
# 1781417245
# Number of dets after get_bias_flags:  796.0  current yield  0.9255813953488372
# Number of dets with noise estimate:  654.0  current yield  0.7604651162790698
# 1781420853
# Number of dets after get_bias_flags:  796.0  current yield  0.9255813953488372
# Number of dets with noise estimate:  603.0  current yield  0.7011627906976744
# 1781424458
# Number of dets after get_bias_flags:  797.0  current yield  0.9267441860465117
# Number of dets with noise estimate:  573.0  current yield  0.6662790697674419
# 1781432138
# Number of dets after get_bias_flags:  795.0  current yield  0.9244186046511628
# Number of dets with noise estimate:  633.0  current yield  0.736046511627907
# 1781435354
# Number of dets after get_bias_flags:  796.0  current yield  0.9255813953488372
# Number of dets with noise estimate:  592.0  current yield  0.6883720930232559
# 1781454537
# Number of dets after get_bias_flags:  783.0  current yield  0.9104651162790698
# Number of dets with noise estimate:  735.0  current yield  0.8546511627906976
# 1781457501
# Number of dets after get_bias_flags:  794.0  current yield  0.9232558139534883
# Number of dets with noise estimate:  714.0  current yield  0.8302325581395349
# 1781459631
# Number of dets after get_bias_flags:  794.0  current yield  0.9232558139534883
# Number of dets with noise estimate:  747.0  current yield  0.8686046511627907
# 1781463233
# Number of dets after get_bias_flags:  787.0  current yield  0.9151162790697674
# Number of dets with noise estimate:  740.0  current yield  0.8604651162790697
# 1781469817
# Number of dets after get_bias_flags:  781.0  current yield  0.9081395348837209
# Number of dets with noise estimate:  730.0  current yield  0.8488372093023255
# 1781473426
# Number of dets after get_bias_flags:  791.0  current yield  0.9197674418604651
# Number of dets with noise estimate:  734.0  current yield  0.8534883720930233
# 1781477032
# Number of dets after get_bias_flags:  798.0  current yield  0.9279069767441861
# Number of dets with noise estimate:  684.0  current yield  0.7953488372093023

# %%
import matplotlib.dates as mdates
fig, ax = plt.subplots()
noise = ax.plot(times, noise_yields, label="Noise yields")
bias = ax.plot(times, bias_yields, label="Bias yields")

ax2 = ax.twinx()  
pw = ax2.plot(times, pwvs, label="PWV", c="black", alpha = 1, linestyle="--")

ax.set_xlabel("Time")
ax.set_ylabel("Yield")
ax.set_ylim(0, 1)
ax2.set_ylim(0,2)
ax2.set_ylabel("PWV")

ax.axhline(pton_df.loc[pton_df.labels==f"{band}_{ufm}", "yields"].to_numpy(), label="PTon")

plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=2))
plt.gcf().autofmt_xdate()

lns = noise+bias+pw
labs = [l.get_label() for l in lns]
ax.legend(lns, labs)
plt.title(f"Yield for UFM {ufm} band {band}")
plt.savefig(f"../plts/yields/yield_{ufm}_{band}.pdf", dpi=600)
plt.savefig(f"../plts/yields/yield_{ufm}_{band}.png", dpi=600)

plt.show()

# %% [markdown]
# # SO Nominal Yields

# %%
start = dt.datetime(2025, 10, 1, tzinfo=dt.timezone.utc)
end = dt.datetime(2025, 10, 15, tzinfo=dt.timezone.utc)


obs_list = ctx.obsdb.query(
    f"{end.timestamp()} > timestamp and timestamp > {start.timestamp()} and type=='obs' and subtype=='cmb'"
)

obs_ids_list = []
for i, obs in enumerate(obs_list):
    obs_ids_list.append(str(obs["obs_id"]))

# %%
old_ctx = core.Context("../ctxs/old_smurf_det_preproc.yaml")
metas = []
for obs_id in obs_ids_list:
    if ot in obs_id:
        print(obs_id)
        try:
            meta = old_ctx.get_meta(obs_id,dets={"dets:stream_id": "ufm_" + str(ufm), "dets:wafer.bandpass": "f" + str(band),},)
            metas.append(meta)
            
        except:
            continue
# Out:
# obs_1759277309_lati4_111
# obs_1759279469_lati4_111
# obs_1759283082_lati4_111
# obs_1759286672_lati4_111
# obs_1759291142_lati4_111
# obs_1759293429_lati4_111
# obs_1759297035_lati4_111
# obs_1759300634_lati4_111
# obs_1759304241_lati4_111
# obs_1759307681_lati4_111
# obs_1759309856_lati4_111
# obs_1759313445_lati4_111
# obs_1759319136_lati4_111
# obs_1759321587_lati4_111
# obs_1759325207_lati4_111
# obs_1759332347_lati4_111
# obs_1759337257_lati4_111
# obs_1759339814_lati4_111
# obs_1759352281_lati4_111
# obs_1759354032_lati4_111
# obs_1759357620_lati4_111
# obs_1759367543_lati4_111
# obs_1759369163_lati4_111
# obs_1759372751_lati4_111
# obs_1759377299_lati4_111
# obs_1759379466_lati4_111
# obs_1759383059_lati4_111
# obs_1759386659_lati4_111
# obs_1759390265_lati4_111
# obs_1759393847_lati4_111
# obs_1759395572_lati4_111
# obs_1759399155_lati4_111
# obs_1759404891_lati4_111
# obs_1759407263_lati4_111
# obs_1759410834_lati4_111
# obs_1759438885_lati4_111
# obs_1759441252_lati4_111
# obs_1759444834_lati4_111
# obs_1759448377_lati4_111
# obs_1759450536_lati4_111
# obs_1759451544_lati4_111
# obs_1759455156_lati4_111
# obs_1759458749_lati4_111
# obs_1759463436_lati4_111
# obs_1759466072_lati4_111
# obs_1759469678_lati4_111
# obs_1759473271_lati4_111
# obs_1759477929_lati4_111
# obs_1759479995_lati4_111
# obs_1759481863_lati4_111
# obs_1759489599_lati4_111
# obs_1759492854_lati4_111
# obs_1759496440_lati4_111
# obs_1759500042_lati4_111
# obs_1759502359_lati4_111
# obs_1759524580_lati4_111
# obs_1759527630_lati4_111
# obs_1759530607_lati4_111
# obs_1759534186_lati4_111
# obs_1759535798_lati4_111
# obs_1759539190_lati4_111
# obs_1759543848_lati4_111
# obs_1759546387_lati4_111
# obs_1759549596_lati4_111
# obs_1759553208_lati4_111
# obs_1759556808_lati4_111
# obs_1759560406_lati4_111
# obs_1759565258_lati4_111
# obs_1759567279_lati4_111
# obs_1759570853_lati4_111
# obs_1759575168_lati4_111
# obs_1759577056_lati4_111
# obs_1759580652_lati4_111
# obs_1759584257_lati4_111
# obs_1759588556_lati4_111
# obs_1759592767_lati4_111
# obs_1759595159_lati4_111
# obs_1759597082_lati4_111
# obs_1759600640_lati4_111
# obs_1759610931_lati4_111
# obs_1759614270_lati4_111
# obs_1759616864_lati4_111
# obs_1759620278_lati4_111
# obs_1759622007_lati4_111
# obs_1759624898_lati4_111
# obs_1759628492_lati4_111
# obs_1759632102_lati4_111
# obs_1759635756_lati4_111
# obs_1759638263_lati4_111
# obs_1759641864_lati4_111
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/metadata/lat/manifests/preprocess/lat_preprocess_cmb_240409m/process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess', 'drop_fields': ['frequency_cutoffs', 'gain_avg']}
#
#   request: {'obs:obs_id': 'obs_1759641864_lati4_111', 'dets:stream_id': 'ufm_mv49', 'dets:wafer.bandpass': 'f090'}
# obs_1759645464_lati4_111
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/metadata/lat/manifests/preprocess/lat_preprocess_cmb_240409m/process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess', 'drop_fields': ['frequency_cutoffs', 'gain_avg']}
#
#   request: {'obs:obs_id': 'obs_1759645464_lati4_111', 'dets:stream_id': 'ufm_mv49', 'dets:wafer.bandpass': 'f090'}
# obs_1759649066_lati4_111
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/metadata/lat/manifests/preprocess/lat_preprocess_cmb_240409m/process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess', 'drop_fields': ['frequency_cutoffs', 'gain_avg']}
#
#   request: {'obs:obs_id': 'obs_1759649066_lati4_111', 'dets:stream_id': 'ufm_mv49', 'dets:wafer.bandpass': 'f090'}
# obs_1759652373_lati4_111
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/metadata/lat/manifests/preprocess/lat_preprocess_cmb_240409m/process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess', 'drop_fields': ['frequency_cutoffs', 'gain_avg']}
#
#   request: {'obs:obs_id': 'obs_1759652373_lati4_111', 'dets:stream_id': 'ufm_mv49', 'dets:wafer.bandpass': 'f090'}
# obs_1759654105_lati4_111
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/metadata/lat/manifests/preprocess/lat_preprocess_cmb_240409m/process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess', 'drop_fields': ['frequency_cutoffs', 'gain_avg']}
#
#   request: {'obs:obs_id': 'obs_1759654105_lati4_111', 'dets:stream_id': 'ufm_mv49', 'dets:wafer.bandpass': 'f090'}
# obs_1759657717_lati4_111
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/metadata/lat/manifests/preprocess/lat_preprocess_cmb_240409m/process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess', 'drop_fields': ['frequency_cutoffs', 'gain_avg']}
#
#   request: {'obs:obs_id': 'obs_1759657717_lati4_111', 'dets:stream_id': 'ufm_mv49', 'dets:wafer.bandpass': 'f090'}
# obs_1759663314_lati4_111
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/metadata/lat/manifests/preprocess/lat_preprocess_cmb_240409m/process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess', 'drop_fields': ['frequency_cutoffs', 'gain_avg']}
#
#   request: {'obs:obs_id': 'obs_1759663314_lati4_111', 'dets:stream_id': 'ufm_mv49', 'dets:wafer.bandpass': 'f090'}
# obs_1759665543_lati4_111
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/metadata/lat/manifests/preprocess/lat_preprocess_cmb_240409m/process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess', 'drop_fields': ['frequency_cutoffs', 'gain_avg']}
#
#   request: {'obs:obs_id': 'obs_1759665543_lati4_111', 'dets:stream_id': 'ufm_mv49', 'dets:wafer.bandpass': 'f090'}
# obs_1759667020_lati4_111
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/metadata/lat/manifests/preprocess/lat_preprocess_cmb_240409m/process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess', 'drop_fields': ['frequency_cutoffs', 'gain_avg']}
#
#   request: {'obs:obs_id': 'obs_1759667020_lati4_111', 'dets:stream_id': 'ufm_mv49', 'dets:wafer.bandpass': 'f090'}
# obs_1759669617_lati4_111
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/metadata/lat/manifests/preprocess/lat_preprocess_cmb_240409m/process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess', 'drop_fields': ['frequency_cutoffs', 'gain_avg']}
#
#   request: {'obs:obs_id': 'obs_1759669617_lati4_111', 'dets:stream_id': 'ufm_mv49', 'dets:wafer.bandpass': 'f090'}
# obs_1759678670_lati4_111
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/metadata/lat/manifests/preprocess/lat_preprocess_cmb_240409m/process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess', 'drop_fields': ['frequency_cutoffs', 'gain_avg']}
#
#   request: {'obs:obs_id': 'obs_1759678670_lati4_111', 'dets:stream_id': 'ufm_mv49', 'dets:wafer.bandpass': 'f090'}
# obs_1759679925_lati4_111
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/metadata/lat/manifests/preprocess/lat_preprocess_cmb_240409m/process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess', 'drop_fields': ['frequency_cutoffs', 'gain_avg']}
#
#   request: {'obs:obs_id': 'obs_1759679925_lati4_111', 'dets:stream_id': 'ufm_mv49', 'dets:wafer.bandpass': 'f090'}
# obs_1759683544_lati4_111
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/metadata/lat/manifests/preprocess/lat_preprocess_cmb_240409m/process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess', 'drop_fields': ['frequency_cutoffs', 'gain_avg']}
#
#   request: {'obs:obs_id': 'obs_1759683544_lati4_111', 'dets:stream_id': 'ufm_mv49', 'dets:wafer.bandpass': 'f090'}
# obs_1759684659_lati4_111
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/metadata/lat/manifests/preprocess/lat_preprocess_cmb_240409m/process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess', 'drop_fields': ['frequency_cutoffs', 'gain_avg']}
#
#   request: {'obs:obs_id': 'obs_1759684659_lati4_111', 'dets:stream_id': 'ufm_mv49', 'dets:wafer.bandpass': 'f090'}
# obs_1759687144_lati4_111
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/metadata/lat/manifests/preprocess/lat_preprocess_cmb_240409m/process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess', 'drop_fields': ['frequency_cutoffs', 'gain_avg']}
#
#   request: {'obs:obs_id': 'obs_1759687144_lati4_111', 'dets:stream_id': 'ufm_mv49', 'dets:wafer.bandpass': 'f090'}
# obs_1759700220_lati4_111
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/metadata/lat/manifests/preprocess/lat_preprocess_cmb_240409m/process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess', 'drop_fields': ['frequency_cutoffs', 'gain_avg']}
#
#   request: {'obs:obs_id': 'obs_1759700220_lati4_111', 'dets:stream_id': 'ufm_mv49', 'dets:wafer.bandpass': 'f090'}
# obs_1759702591_lati4_111
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/metadata/lat/manifests/preprocess/lat_preprocess_cmb_240409m/process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess', 'drop_fields': ['frequency_cutoffs', 'gain_avg']}
#
#   request: {'obs:obs_id': 'obs_1759702591_lati4_111', 'dets:stream_id': 'ufm_mv49', 'dets:wafer.bandpass': 'f090'}
# obs_1759709252_lati4_111
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/metadata/lat/manifests/preprocess/lat_preprocess_cmb_240409m/process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess', 'drop_fields': ['frequency_cutoffs', 'gain_avg']}
#
#   request: {'obs:obs_id': 'obs_1759709252_lati4_111', 'dets:stream_id': 'ufm_mv49', 'dets:wafer.bandpass': 'f090'}
# obs_1759710486_lati4_111
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/metadata/lat/manifests/preprocess/lat_preprocess_cmb_240409m/process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess', 'drop_fields': ['frequency_cutoffs', 'gain_avg']}
#
#   request: {'obs:obs_id': 'obs_1759710486_lati4_111', 'dets:stream_id': 'ufm_mv49', 'dets:wafer.bandpass': 'f090'}
# obs_1759714082_lati4_111
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/metadata/lat/manifests/preprocess/lat_preprocess_cmb_240409m/process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess', 'drop_fields': ['frequency_cutoffs', 'gain_avg']}
#
#   request: {'obs:obs_id': 'obs_1759714082_lati4_111', 'dets:stream_id': 'ufm_mv49', 'dets:wafer.bandpass': 'f090'}
# obs_1759717675_lati4_111
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/metadata/lat/manifests/preprocess/lat_preprocess_cmb_240409m/process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess', 'drop_fields': ['frequency_cutoffs', 'gain_avg']}
#
#   request: {'obs:obs_id': 'obs_1759717675_lati4_111', 'dets:stream_id': 'ufm_mv49', 'dets:wafer.bandpass': 'f090'}
# obs_1759721918_lati4_111
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/metadata/lat/manifests/preprocess/lat_preprocess_cmb_240409m/process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess', 'drop_fields': ['frequency_cutoffs', 'gain_avg']}
#
#   request: {'obs:obs_id': 'obs_1759721918_lati4_111', 'dets:stream_id': 'ufm_mv49', 'dets:wafer.bandpass': 'f090'}
# obs_1759723993_lati4_111
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/metadata/lat/manifests/preprocess/lat_preprocess_cmb_240409m/process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess', 'drop_fields': ['frequency_cutoffs', 'gain_avg']}
#
#   request: {'obs:obs_id': 'obs_1759723993_lati4_111', 'dets:stream_id': 'ufm_mv49', 'dets:wafer.bandpass': 'f090'}
# obs_1759727587_lati4_111
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/metadata/lat/manifests/preprocess/lat_preprocess_cmb_240409m/process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess', 'drop_fields': ['frequency_cutoffs', 'gain_avg']}
#
#   request: {'obs:obs_id': 'obs_1759727587_lati4_111', 'dets:stream_id': 'ufm_mv49', 'dets:wafer.bandpass': 'f090'}
# obs_1759731173_lati4_111
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/metadata/lat/manifests/preprocess/lat_preprocess_cmb_240409m/process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess', 'drop_fields': ['frequency_cutoffs', 'gain_avg']}
#
#   request: {'obs:obs_id': 'obs_1759731173_lati4_111', 'dets:stream_id': 'ufm_mv49', 'dets:wafer.bandpass': 'f090'}
# obs_1759734789_lati4_111
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/metadata/lat/manifests/preprocess/lat_preprocess_cmb_240409m/process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess', 'drop_fields': ['frequency_cutoffs', 'gain_avg']}
#
#   request: {'obs:obs_id': 'obs_1759734789_lati4_111', 'dets:stream_id': 'ufm_mv49', 'dets:wafer.bandpass': 'f090'}
# obs_1759738537_lati4_111
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/metadata/lat/manifests/preprocess/lat_preprocess_cmb_240409m/process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess', 'drop_fields': ['frequency_cutoffs', 'gain_avg']}
#
#   request: {'obs:obs_id': 'obs_1759738537_lati4_111', 'dets:stream_id': 'ufm_mv49', 'dets:wafer.bandpass': 'f090'}
# obs_1759740101_lati4_111
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/metadata/lat/manifests/preprocess/lat_preprocess_cmb_240409m/process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess', 'drop_fields': ['frequency_cutoffs', 'gain_avg']}
#
#   request: {'obs:obs_id': 'obs_1759740101_lati4_111', 'dets:stream_id': 'ufm_mv49', 'dets:wafer.bandpass': 'f090'}
# obs_1759748082_lati4_111
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/metadata/lat/manifests/preprocess/lat_preprocess_cmb_240409m/process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess', 'drop_fields': ['frequency_cutoffs', 'gain_avg']}
#
#   request: {'obs:obs_id': 'obs_1759748082_lati4_111', 'dets:stream_id': 'ufm_mv49', 'dets:wafer.bandpass': 'f090'}
# obs_1760046785_lati4_011
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/metadata/lat/manifests/preprocess/lat_preprocess_cmb_240409m/process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess', 'drop_fields': ['frequency_cutoffs', 'gain_avg']}
#
#   request: {'obs:obs_id': 'obs_1760050700_lati4_011', 'dets:stream_id': 'ufm_mv49', 'dets:wafer.bandpass': 'f090'}
# obs_1760050700_lati4_011
# obs_1760054622_lati4_011
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/metadata/lat/manifests/preprocess/lat_preprocess_cmb_240409m/process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess', 'drop_fields': ['frequency_cutoffs', 'gain_avg']}
#
#   request: {'obs:obs_id': 'obs_1760054622_lati4_011', 'dets:stream_id': 'ufm_mv49', 'dets:wafer.bandpass': 'f090'}
#
#
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/metadata/lat/manifests/preprocess/lat_preprocess_cmb_240409m/process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess', 'drop_fields': ['frequency_cutoffs', 'gain_avg']}
#
#   request: {'obs:obs_id': 'obs_1760058561_lati4_011', 'dets:stream_id': 'ufm_mv49', 'dets:wafer.bandpass': 'f090'}
# obs_1760058561_lati4_011
# obs_1760066557_lati4_011
# obs_1760069243_lati4_011
# obs_1760072847_lati4_011
# obs_1760076456_lati4_011
# obs_1760081099_lati4_111
# obs_1760083172_lati4_111
# obs_1760084066_lati4_111
# obs_1760087643_lati4_111
# obs_1760091251_lati4_111
# obs_1760094856_lati4_111
# obs_1760099505_lati4_111
# obs_1760102079_lati4_111
# obs_1760105642_lati4_011
# obs_1760109256_lati4_011
# obs_1760112842_lati4_011
# obs_1760117313_lati4_011
# obs_1760118612_lati4_011
# obs_1760122212_lati4_011
# obs_1760125795_lati4_011
# obs_1760129407_lati4_011
# obs_1760133215_lati4_011
# obs_1760136991_lati4_011
# obs_1760139964_lati4_011
# obs_1760143539_lati4_011
# obs_1760148191_lati4_011
# obs_1760150776_lati4_011
# obs_1760154336_lati4_011
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/metadata/lat/manifests/preprocess/lat_preprocess_cmb_240409m/process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess', 'drop_fields': ['frequency_cutoffs', 'gain_avg']}
#
#   request: {'obs:obs_id': 'obs_1760157932_lati4_011', 'dets:stream_id': 'ufm_mv49', 'dets:wafer.bandpass': 'f090'}
# obs_1760157932_lati4_011
# obs_1760159496_lati4_011
# obs_1760164764_lati4_011
# obs_1760168679_lati4_011
# obs_1760177010_lati4_011
# obs_1760180019_lati4_011
# obs_1760182835_lati4_011
# obs_1760187489_lati4_011
# obs_1760191564_lati4_011
# obs_1760193637_lati4_011
# obs_1760199567_lati4_011
# obs_1760202634_lati4_011
# obs_1760204864_lati4_011
# obs_1760208436_lati4_011
# obs_1760212041_lati4_011
# obs_1760215644_lati4_011
# obs_1760217637_lati4_011
# obs_1760219730_lati4_011
# obs_1760224166_lati4_011
# obs_1760225477_lati4_011
# obs_1760229082_lati4_011
# obs_1760233729_lati4_011
# obs_1760236310_lati4_011
# obs_1760239879_lati4_011
# obs_1760243489_lati4_011
# obs_1760245746_lati4_011
# obs_1760249668_lati4_011
# obs_1760252724_lati4_011
# obs_1760256301_lati4_011
# obs_1760260961_lati4_011
# obs_1760263572_lati4_011
# obs_1760266461_lati4_011
# obs_1760268509_lati4_011
# obs_1760272116_lati4_011
# obs_1760276762_lati4_011
# obs_1760279347_lati4_011
# obs_1760282912_lati4_011
# obs_1760286512_lati4_011
# obs_1760289361_lati4_011
# obs_1760292981_lati4_011
# obs_1760295554_lati4_011
# obs_1760299119_lati4_011
# obs_1760303132_lati4_011
# obs_1760305619_lati4_011
# obs_1760311254_lati4_011
# obs_1760313271_lati4_011
# obs_1760317881_lati4_011
# obs_1760320457_lati4_011
# obs_1760324020_lati4_011
# obs_1760327622_lati4_011
# obs_1760331877_lati4_011
# obs_1760335953_lati4_011
# obs_1760339358_lati4_011
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/metadata/lat/manifests/preprocess/lat_preprocess_cmb_240409m/process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess', 'drop_fields': ['frequency_cutoffs', 'gain_avg']}
#
#   request: {'obs:obs_id': 'obs_1760342959_lati4_011', 'dets:stream_id': 'ufm_mv49', 'dets:wafer.bandpass': 'f090'}
# obs_1760342959_lati4_011
# obs_1760347612_lati4_011
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/metadata/lat/manifests/preprocess/lat_preprocess_cmb_240409m/process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess', 'drop_fields': ['frequency_cutoffs', 'gain_avg']}
#
#   request: {'obs:obs_id': 'obs_1760347612_lati4_011', 'dets:stream_id': 'ufm_mv49', 'dets:wafer.bandpass': 'f090'}
# obs_1760350212_lati4_011
# obs_1760352771_lati4_011
# obs_1760354574_lati4_011
# obs_1760358154_lati4_011
# obs_1760362804_lati4_011
# obs_1760365375_lati4_011
# obs_1760368945_lati4_011
# obs_1760372556_lati4_011
# obs_1760375819_lati4_011
# obs_1760379753_lati4_011
# ERROR: sotodlib.core.metadata.loader: An error occurred while processing a meta entry:
#
#   spec:    {'db': '/global/cfs/cdirs/sobs/metadata/lat/manifests/preprocess/lat_preprocess_cmb_240409m/process_archive.sqlite', 'label': 'preprocess', 'unpack': 'preprocess', 'drop_fields': ['frequency_cutoffs', 'gain_avg']}
#
#   request: {'obs:obs_id': 'obs_1760382339_lati4_011', 'dets:stream_id': 'ufm_mv49', 'dets:wafer.bandpass': 'f090'}
# obs_1760382339_lati4_011
# obs_1760385904_lati4_011
# obs_1760389778_lati4_011
# obs_1760391754_lati4_011
# obs_1760395472_lati4_011
# obs_1760398532_lati4_011
# obs_1760413537_lati4_111
# obs_1760414643_lati4_111
# obs_1760418111_lati4_111
# obs_1760422471_lati4_111
# obs_1760424904_lati4_111
# obs_1760429552_lati4_111
# obs_1760432126_lati4_111
# obs_1760435696_lati4_111
# obs_1760438975_lati4_111
# obs_1760441200_lati4_111
# obs_1760445841_lati4_111
# obs_1760448413_lati4_111
# obs_1760451976_lati4_111
# obs_1760455590_lati4_111
# obs_1760459186_lati4_111
# obs_1760463336_lati4_111
# obs_1760465802_lati4_111
# obs_1760469402_lati4_111
# obs_1760473001_lati4_111
# obs_1760475937_lati4_111
# obs_1760477904_lati4_111
# obs_1760481993_lati4_111
# obs_1760484766_lati4_111

# %%
obs_ids = []
times = []
bias_yields = []
noise_yields = []
pwvs = []

for i in range(len(metas)):
    meta = metas[i]
    obs_id = meta.obs_info.obs_id
    if "mv" in ufm:
        if band == "090":
            ufm_band = 1
        elif band == "150":
            ufm_band = 2
    if "uv" in ufm:
        if band == "220":
            ufm_band = 1
        elif band == "280":
            ufm_band = 2
    flags = get_det_bias_flags(meta).det_bias_flags
    meta.restrict("dets", ~core.flagman.has_any_cuts(flags))
    wafer_flag = np.array([ufm in _ufm for _ufm in meta.det_info.stream_id])
    
    if len(wafer_flag) == 0:
        print(f"No det_info for obs {obs_id}")

    obs_ids.append(obs_id.split("_")[1])
    print(obs_ids[i])
    times.append(dt.datetime.fromtimestamp(int(obs_id.split("_")[1])))
    bias_yield = meta.shape[0]/860
    bias_yields.append(bias_yield)
        
    print("Number of dets after get_bias_flags: ", bias_yield*860, " current yield ", bias_yield)
    bp = (meta.det_cal.bg % 4) // 2
    
    if ufm_band == 1:
        net_flag = wafer_flag * (bp == 0)
    elif ufm_band == 2:
        net_flag = wafer_flag * (bp == 1)
    
    raw_cal = np.nanmedian(meta.abscal.raw_abscal_rj[net_flag])
    if "noise" in meta.preprocess:
        wnoise = meta.preprocess.noise.white_noise[net_flag]
    elif "noiseT" in meta.preprocess:
        wnoise = meta.preprocess.noiseT.white_noise[net_flag]
    else:
        print(f"Error: no valid noise key in {meta.preprocess.keys()}")
    ndet = len(np.where(wnoise != 0)[0])
    noise_yield = ndet/860
    noise_yields.append(noise_yield)
    print("Number of dets with noise estimate: ", noise_yield*860, " current yield ", noise_yield)
    pwvs.append(pwv((obs_id.split("_")[1])))
# Out:
# 1759277309
# Number of dets after get_bias_flags:  380.0  current yield  0.4418604651162791
# Number of dets with noise estimate:  378.0  current yield  0.43953488372093025
# 1759279469
# Number of dets after get_bias_flags:  392.0  current yield  0.4558139534883721
# Number of dets with noise estimate:  375.0  current yield  0.436046511627907
# 1759283082
# Number of dets after get_bias_flags:  390.0  current yield  0.45348837209302323
# Number of dets with noise estimate:  375.0  current yield  0.436046511627907
# 1759286672
# Number of dets after get_bias_flags:  392.0  current yield  0.4558139534883721
# Number of dets with noise estimate:  381.0  current yield  0.44302325581395346
# 1759291142
# Number of dets after get_bias_flags:  380.0  current yield  0.4418604651162791
# Number of dets with noise estimate:  377.0  current yield  0.4383720930232558
# 1759293429
# Number of dets after get_bias_flags:  377.0  current yield  0.4383720930232558
# Number of dets with noise estimate:  373.0  current yield  0.43372093023255814
# 1759297035
# Number of dets after get_bias_flags:  377.0  current yield  0.4383720930232558
# Number of dets with noise estimate:  368.0  current yield  0.42790697674418604
# 1759300634
# Number of dets after get_bias_flags:  377.0  current yield  0.4383720930232558
# Number of dets with noise estimate:  368.0  current yield  0.42790697674418604
# 1759304241
# Number of dets after get_bias_flags:  379.0  current yield  0.44069767441860463
# Number of dets with noise estimate:  377.0  current yield  0.4383720930232558
# 1759307681
# Number of dets after get_bias_flags:  372.0  current yield  0.4325581395348837
# Number of dets with noise estimate:  370.0  current yield  0.43023255813953487
# 1759309856
# Number of dets after get_bias_flags:  374.0  current yield  0.43488372093023253
# Number of dets with noise estimate:  365.0  current yield  0.42441860465116277
# 1759313445
# Number of dets after get_bias_flags:  373.0  current yield  0.43372093023255814
# Number of dets with noise estimate:  367.0  current yield  0.42674418604651165
# 1759319136
# Number of dets after get_bias_flags:  372.0  current yield  0.4325581395348837
# Number of dets with noise estimate:  370.0  current yield  0.43023255813953487
# 1759321587
# Number of dets after get_bias_flags:  372.0  current yield  0.4325581395348837
# Number of dets with noise estimate:  282.0  current yield  0.32790697674418606
# 1759325207
# Number of dets after get_bias_flags:  375.0  current yield  0.436046511627907
# Number of dets with noise estimate:  370.0  current yield  0.43023255813953487
# 1759332347
# Number of dets after get_bias_flags:  383.0  current yield  0.44534883720930235
# Number of dets with noise estimate:  381.0  current yield  0.44302325581395346
# 1759337257
# Number of dets after get_bias_flags:  372.0  current yield  0.4325581395348837
# Number of dets with noise estimate:  369.0  current yield  0.4290697674418605
# 1759339814
# Number of dets after get_bias_flags:  371.0  current yield  0.4313953488372093
# Number of dets with noise estimate:  176.0  current yield  0.20465116279069767
# 1759352281
# Number of dets after get_bias_flags:  377.0  current yield  0.4383720930232558
# Number of dets with noise estimate:  344.0  current yield  0.4
# 1759354032
# Number of dets after get_bias_flags:  372.0  current yield  0.4325581395348837
# Number of dets with noise estimate:  369.0  current yield  0.4290697674418605
# 1759357620
# Number of dets after get_bias_flags:  371.0  current yield  0.4313953488372093
# Number of dets with noise estimate:  370.0  current yield  0.43023255813953487
# 1759367543
# Number of dets after get_bias_flags:  399.0  current yield  0.46395348837209305
# Number of dets with noise estimate:  391.0  current yield  0.45465116279069767
# 1759369163
# Number of dets after get_bias_flags:  405.0  current yield  0.47093023255813954
# Number of dets with noise estimate:  370.0  current yield  0.43023255813953487
# 1759372751
# Number of dets after get_bias_flags:  405.0  current yield  0.47093023255813954
# Number of dets with noise estimate:  370.0  current yield  0.43023255813953487
# 1759377299
# Number of dets after get_bias_flags:  379.0  current yield  0.44069767441860463
# Number of dets with noise estimate:  372.0  current yield  0.4325581395348837
# 1759379466
# Number of dets after get_bias_flags:  378.0  current yield  0.43953488372093025
# Number of dets with noise estimate:  367.0  current yield  0.42674418604651165
# 1759383059
# Number of dets after get_bias_flags:  378.0  current yield  0.43953488372093025
# Number of dets with noise estimate:  365.0  current yield  0.42441860465116277
# 1759386659
# Number of dets after get_bias_flags:  379.0  current yield  0.44069767441860463
# Number of dets with noise estimate:  368.0  current yield  0.42790697674418604
# 1759390265
# Number of dets after get_bias_flags:  380.0  current yield  0.4418604651162791
# Number of dets with noise estimate:  373.0  current yield  0.43372093023255814
# 1759393847
# Number of dets after get_bias_flags:  372.0  current yield  0.4325581395348837
# Number of dets with noise estimate:  371.0  current yield  0.4313953488372093
# 1759395572
# Number of dets after get_bias_flags:  371.0  current yield  0.4313953488372093
# Number of dets with noise estimate:  366.0  current yield  0.4255813953488372
# 1759399155
# Number of dets after get_bias_flags:  371.0  current yield  0.4313953488372093
# Number of dets with noise estimate:  365.0  current yield  0.42441860465116277
# 1759404891
# Number of dets after get_bias_flags:  372.0  current yield  0.4325581395348837
# Number of dets with noise estimate:  371.0  current yield  0.4313953488372093
# 1759407263
# Number of dets after get_bias_flags:  373.0  current yield  0.43372093023255814
# Number of dets with noise estimate:  367.0  current yield  0.42674418604651165
# 1759410834
# Number of dets after get_bias_flags:  371.0  current yield  0.4313953488372093
# Number of dets with noise estimate:  370.0  current yield  0.43023255813953487
# 1759438885
# Number of dets after get_bias_flags:  376.0  current yield  0.4372093023255814
# Number of dets with noise estimate:  373.0  current yield  0.43372093023255814
# 1759441252
# Number of dets after get_bias_flags:  384.0  current yield  0.44651162790697674
# Number of dets with noise estimate:  377.0  current yield  0.4383720930232558
# 1759444834
# Number of dets after get_bias_flags:  381.0  current yield  0.44302325581395346
# Number of dets with noise estimate:  373.0  current yield  0.43372093023255814
# 1759448377
# Number of dets after get_bias_flags:  373.0  current yield  0.43372093023255814
# Number of dets with noise estimate:  373.0  current yield  0.43372093023255814
# 1759450536
# Number of dets after get_bias_flags:  393.0  current yield  0.4569767441860465
# Number of dets with noise estimate:  381.0  current yield  0.44302325581395346
# 1759451544
# Number of dets after get_bias_flags:  397.0  current yield  0.46162790697674416
# Number of dets with noise estimate:  369.0  current yield  0.4290697674418605
# 1759455156
# Number of dets after get_bias_flags:  398.0  current yield  0.4627906976744186
# Number of dets with noise estimate:  371.0  current yield  0.4313953488372093
# 1759458749
# Number of dets after get_bias_flags:  396.0  current yield  0.4604651162790698
# Number of dets with noise estimate:  376.0  current yield  0.4372093023255814
# 1759463436
# Number of dets after get_bias_flags:  422.0  current yield  0.4906976744186046
# Number of dets with noise estimate:  395.0  current yield  0.45930232558139533
# 1759466072
# Number of dets after get_bias_flags:  409.0  current yield  0.4755813953488372
# Number of dets with noise estimate:  380.0  current yield  0.4418604651162791
# 1759469678
# Number of dets after get_bias_flags:  413.0  current yield  0.48023255813953486
# Number of dets with noise estimate:  381.0  current yield  0.44302325581395346
# 1759473271
# Number of dets after get_bias_flags:  412.0  current yield  0.4790697674418605
# Number of dets with noise estimate:  393.0  current yield  0.4569767441860465
# 1759477929
# Number of dets after get_bias_flags:  398.0  current yield  0.4627906976744186
# Number of dets with noise estimate:  396.0  current yield  0.4604651162790698
# 1759479995
# Number of dets after get_bias_flags:  414.0  current yield  0.4813953488372093
# Number of dets with noise estimate:  408.0  current yield  0.4744186046511628
# 1759481863
# Number of dets after get_bias_flags:  402.0  current yield  0.46744186046511627
# Number of dets with noise estimate:  377.0  current yield  0.4383720930232558
# 1759489599
# Number of dets after get_bias_flags:  397.0  current yield  0.46162790697674416
# Number of dets with noise estimate:  379.0  current yield  0.44069767441860463
# 1759492854
# Number of dets after get_bias_flags:  397.0  current yield  0.46162790697674416
# Number of dets with noise estimate:  378.0  current yield  0.43953488372093025
# 1759496440
# Number of dets after get_bias_flags:  267.0  current yield  0.31046511627906975
# Number of dets with noise estimate:  255.00000000000003  current yield  0.29651162790697677
# 1759500042
# Number of dets after get_bias_flags:  392.0  current yield  0.4558139534883721
# Number of dets with noise estimate:  391.0  current yield  0.45465116279069767
# 1759502359
# Number of dets after get_bias_flags:  406.0  current yield  0.4720930232558139
# Number of dets with noise estimate:  397.0  current yield  0.46162790697674416
# 1759524580
# Number of dets after get_bias_flags:  787.0  current yield  0.9151162790697674
# Number of dets with noise estimate:  784.0  current yield  0.9116279069767442
# 1759527630
# Number of dets after get_bias_flags:  788.0  current yield  0.9162790697674419
# Number of dets with noise estimate:  714.0  current yield  0.8302325581395349
# 1759530607
# Number of dets after get_bias_flags:  788.0  current yield  0.9162790697674419
# Number of dets with noise estimate:  784.0  current yield  0.9116279069767442
# 1759534186
# Number of dets after get_bias_flags:  788.0  current yield  0.9162790697674419
# Number of dets with noise estimate:  785.0  current yield  0.9127906976744186
# 1759535798
# Number of dets after get_bias_flags:  788.0  current yield  0.9162790697674419
# Number of dets with noise estimate:  784.0  current yield  0.9116279069767442
# 1759539190
# Number of dets after get_bias_flags:  790.0  current yield  0.9186046511627907
# Number of dets with noise estimate:  790.0  current yield  0.9186046511627907
# 1759543848
# Number of dets after get_bias_flags:  790.0  current yield  0.9186046511627907
# Number of dets with noise estimate:  790.0  current yield  0.9186046511627907
# 1759546387
# Number of dets after get_bias_flags:  789.0  current yield  0.9174418604651163
# Number of dets with noise estimate:  789.0  current yield  0.9174418604651163
# 1759549596
# Number of dets after get_bias_flags:  632.0  current yield  0.7348837209302326
# Number of dets with noise estimate:  631.0  current yield  0.7337209302325581
# 1759553208
# Number of dets after get_bias_flags:  790.0  current yield  0.9186046511627907
# Number of dets with noise estimate:  789.0  current yield  0.9174418604651163
# 1759556808
# Number of dets after get_bias_flags:  790.0  current yield  0.9186046511627907
# Number of dets with noise estimate:  788.0  current yield  0.9162790697674419
# 1759560406
# Number of dets after get_bias_flags:  791.0  current yield  0.9197674418604651
# Number of dets with noise estimate:  789.0  current yield  0.9174418604651163
# 1759565258
# Number of dets after get_bias_flags:  788.0  current yield  0.9162790697674419
# Number of dets with noise estimate:  787.0  current yield  0.9151162790697674
# 1759567279
# Number of dets after get_bias_flags:  788.0  current yield  0.9162790697674419
# Number of dets with noise estimate:  788.0  current yield  0.9162790697674419
# 1759570853
# Number of dets after get_bias_flags:  788.0  current yield  0.9162790697674419
# Number of dets with noise estimate:  788.0  current yield  0.9162790697674419
# 1759575168
# Number of dets after get_bias_flags:  789.0  current yield  0.9174418604651163
# Number of dets with noise estimate:  789.0  current yield  0.9174418604651163
# 1759577056
# Number of dets after get_bias_flags:  789.0  current yield  0.9174418604651163
# Number of dets with noise estimate:  788.0  current yield  0.9162790697674419
# 1759580652
# Number of dets after get_bias_flags:  789.0  current yield  0.9174418604651163
# Number of dets with noise estimate:  788.0  current yield  0.9162790697674419
# 1759584257
# Number of dets after get_bias_flags:  789.0  current yield  0.9174418604651163
# Number of dets with noise estimate:  788.0  current yield  0.9162790697674419
# 1759588556
# Number of dets after get_bias_flags:  788.0  current yield  0.9162790697674419
# Number of dets with noise estimate:  787.0  current yield  0.9151162790697674
# 1759592767
# Number of dets after get_bias_flags:  787.0  current yield  0.9151162790697674
# Number of dets with noise estimate:  669.0  current yield  0.7779069767441861
# 1759595159
# Number of dets after get_bias_flags:  788.0  current yield  0.9162790697674419
# Number of dets with noise estimate:  786.0  current yield  0.913953488372093
# 1759597082
# Number of dets after get_bias_flags:  787.0  current yield  0.9151162790697674
# Number of dets with noise estimate:  551.0  current yield  0.6406976744186047
# 1759600640
# Number of dets after get_bias_flags:  786.0  current yield  0.913953488372093
# Number of dets with noise estimate:  782.0  current yield  0.9093023255813953
# 1759610931
# Number of dets after get_bias_flags:  785.0  current yield  0.9127906976744186
# Number of dets with noise estimate:  779.0  current yield  0.9058139534883721
# 1759614270
# Number of dets after get_bias_flags:  787.0  current yield  0.9151162790697674
# Number of dets with noise estimate:  781.0  current yield  0.9081395348837209
# 1759616864
# Number of dets after get_bias_flags:  787.0  current yield  0.9151162790697674
# Number of dets with noise estimate:  784.0  current yield  0.9116279069767442
# 1759620278
# Number of dets after get_bias_flags:  788.0  current yield  0.9162790697674419
# Number of dets with noise estimate:  787.0  current yield  0.9151162790697674
# 1759622007
# Number of dets after get_bias_flags:  789.0  current yield  0.9174418604651163
# Number of dets with noise estimate:  788.0  current yield  0.9162790697674419
# 1759624898
# Number of dets after get_bias_flags:  788.0  current yield  0.9162790697674419
# Number of dets with noise estimate:  788.0  current yield  0.9162790697674419
# 1759628492
# Number of dets after get_bias_flags:  790.0  current yield  0.9186046511627907
# Number of dets with noise estimate:  790.0  current yield  0.9186046511627907
# 1759632102
# Number of dets after get_bias_flags:  790.0  current yield  0.9186046511627907
# Number of dets with noise estimate:  785.0  current yield  0.9127906976744186
# 1759635756
# Number of dets after get_bias_flags:  790.0  current yield  0.9186046511627907
# Number of dets with noise estimate:  788.0  current yield  0.9162790697674419
# 1759638263
# Number of dets after get_bias_flags:  791.0  current yield  0.9197674418604651
# Number of dets with noise estimate:  207.0  current yield  0.24069767441860465
# 1760046785
# Number of dets after get_bias_flags:  783.0  current yield  0.9104651162790698
# Number of dets with noise estimate:  782.0  current yield  0.9093023255813953
# 1760066557
# Number of dets after get_bias_flags:  631.0  current yield  0.7337209302325581
# Number of dets with noise estimate:  630.0  current yield  0.7325581395348837
# 1760069243
# Number of dets after get_bias_flags:  789.0  current yield  0.9174418604651163
# Number of dets with noise estimate:  789.0  current yield  0.9174418604651163
# 1760072847
# Number of dets after get_bias_flags:  789.0  current yield  0.9174418604651163
# Number of dets with noise estimate:  789.0  current yield  0.9174418604651163
# 1760076456
# Number of dets after get_bias_flags:  789.0  current yield  0.9174418604651163
# Number of dets with noise estimate:  789.0  current yield  0.9174418604651163
# 1760081099
# Number of dets after get_bias_flags:  790.0  current yield  0.9186046511627907
# Number of dets with noise estimate:  790.0  current yield  0.9186046511627907
# 1760083172
# Number of dets after get_bias_flags:  787.0  current yield  0.9151162790697674
# Number of dets with noise estimate:  787.0  current yield  0.9151162790697674
# 1760084066
# Number of dets after get_bias_flags:  788.0  current yield  0.9162790697674419
# Number of dets with noise estimate:  788.0  current yield  0.9162790697674419
# 1760087643
# Number of dets after get_bias_flags:  788.0  current yield  0.9162790697674419
# Number of dets with noise estimate:  786.0  current yield  0.913953488372093
# 1760091251
# Number of dets after get_bias_flags:  785.0  current yield  0.9127906976744186
# Number of dets with noise estimate:  784.0  current yield  0.9116279069767442
# 1760094856
# Number of dets after get_bias_flags:  787.0  current yield  0.9151162790697674
# Number of dets with noise estimate:  784.0  current yield  0.9116279069767442
# 1760099505
# Number of dets after get_bias_flags:  787.0  current yield  0.9151162790697674
# Number of dets with noise estimate:  624.0  current yield  0.7255813953488373
# 1760102079
# Number of dets after get_bias_flags:  786.0  current yield  0.913953488372093
# Number of dets with noise estimate:  785.0  current yield  0.9127906976744186
# 1760105642
# Number of dets after get_bias_flags:  785.0  current yield  0.9127906976744186
# Number of dets with noise estimate:  784.0  current yield  0.9116279069767442
# 1760109256
# Number of dets after get_bias_flags:  781.0  current yield  0.9081395348837209
# Number of dets with noise estimate:  471.0  current yield  0.5476744186046512
# 1760112842
# Number of dets after get_bias_flags:  780.0  current yield  0.9069767441860465
# Number of dets with noise estimate:  778.0  current yield  0.9046511627906977
# 1760117313
# Number of dets after get_bias_flags:  782.0  current yield  0.9093023255813953
# Number of dets with noise estimate:  782.0  current yield  0.9093023255813953
# 1760118612
# Number of dets after get_bias_flags:  780.0  current yield  0.9069767441860465
# Number of dets with noise estimate:  779.0  current yield  0.9058139534883721
# 1760122212
# Number of dets after get_bias_flags:  779.0  current yield  0.9058139534883721
# Number of dets with noise estimate:  779.0  current yield  0.9058139534883721
# 1760125795
# Number of dets after get_bias_flags:  778.0  current yield  0.9046511627906977
# Number of dets with noise estimate:  778.0  current yield  0.9046511627906977
# 1760129407
# Number of dets after get_bias_flags:  778.0  current yield  0.9046511627906977
# Number of dets with noise estimate:  778.0  current yield  0.9046511627906977
# 1760133215
# Number of dets after get_bias_flags:  783.0  current yield  0.9104651162790698
# Number of dets with noise estimate:  783.0  current yield  0.9104651162790698
# 1760136991
# Number of dets after get_bias_flags:  783.0  current yield  0.9104651162790698
# Number of dets with noise estimate:  783.0  current yield  0.9104651162790698
# 1760139964
# Number of dets after get_bias_flags:  785.0  current yield  0.9127906976744186
# Number of dets with noise estimate:  785.0  current yield  0.9127906976744186
# 1760143539
# Number of dets after get_bias_flags:  785.0  current yield  0.9127906976744186
# Number of dets with noise estimate:  784.0  current yield  0.9116279069767442
# 1760148191
# Number of dets after get_bias_flags:  654.0  current yield  0.7604651162790698
# Number of dets with noise estimate:  654.0  current yield  0.7604651162790698
# 1760150776
# Number of dets after get_bias_flags:  785.0  current yield  0.9127906976744186
# Number of dets with noise estimate:  785.0  current yield  0.9127906976744186
# 1760154336
# Number of dets after get_bias_flags:  787.0  current yield  0.9151162790697674
# Number of dets with noise estimate:  786.0  current yield  0.913953488372093
# 1760159496
# Number of dets after get_bias_flags:  787.0  current yield  0.9151162790697674
# Number of dets with noise estimate:  777.0  current yield  0.9034883720930232
# 1760164764
# Number of dets after get_bias_flags:  788.0  current yield  0.9162790697674419
# Number of dets with noise estimate:  785.0  current yield  0.9127906976744186
# 1760168679
# Number of dets after get_bias_flags:  788.0  current yield  0.9162790697674419
# Number of dets with noise estimate:  780.0  current yield  0.9069767441860465
# 1760177010
# Number of dets after get_bias_flags:  787.0  current yield  0.9151162790697674
# Number of dets with noise estimate:  785.0  current yield  0.9127906976744186
# 1760180019
# Number of dets after get_bias_flags:  788.0  current yield  0.9162790697674419
# Number of dets with noise estimate:  786.0  current yield  0.913953488372093
# 1760182835
# Number of dets after get_bias_flags:  789.0  current yield  0.9174418604651163
# Number of dets with noise estimate:  789.0  current yield  0.9174418604651163
# 1760187489
# Number of dets after get_bias_flags:  787.0  current yield  0.9151162790697674
# Number of dets with noise estimate:  786.0  current yield  0.913953488372093
# 1760191564
# Number of dets after get_bias_flags:  788.0  current yield  0.9162790697674419
# Number of dets with noise estimate:  787.0  current yield  0.9151162790697674
# 1760193637
# Number of dets after get_bias_flags:  788.0  current yield  0.9162790697674419
# Number of dets with noise estimate:  787.0  current yield  0.9151162790697674
# 1760199567
# Number of dets after get_bias_flags:  787.0  current yield  0.9151162790697674
# Number of dets with noise estimate:  786.0  current yield  0.913953488372093
# 1760202634
# Number of dets after get_bias_flags:  788.0  current yield  0.9162790697674419
# Number of dets with noise estimate:  787.0  current yield  0.9151162790697674
# 1760204864
# Number of dets after get_bias_flags:  788.0  current yield  0.9162790697674419
# Number of dets with noise estimate:  657.0  current yield  0.763953488372093
# 1760208436
# Number of dets after get_bias_flags:  788.0  current yield  0.9162790697674419
# Number of dets with noise estimate:  787.0  current yield  0.9151162790697674
# 1760212041
# Number of dets after get_bias_flags:  789.0  current yield  0.9174418604651163
# Number of dets with noise estimate:  788.0  current yield  0.9162790697674419
# 1760215644
# Number of dets after get_bias_flags:  788.0  current yield  0.9162790697674419
# Number of dets with noise estimate:  787.0  current yield  0.9151162790697674
# 1760217637
# Number of dets after get_bias_flags:  788.0  current yield  0.9162790697674419
# Number of dets with noise estimate:  787.0  current yield  0.9151162790697674
# 1760219730
# Number of dets after get_bias_flags:  786.0  current yield  0.913953488372093
# Number of dets with noise estimate:  786.0  current yield  0.913953488372093
# 1760224166
# Number of dets after get_bias_flags:  785.0  current yield  0.9127906976744186
# Number of dets with noise estimate:  785.0  current yield  0.9127906976744186
# 1760225477
# Number of dets after get_bias_flags:  785.0  current yield  0.9127906976744186
# Number of dets with noise estimate:  785.0  current yield  0.9127906976744186
# 1760229082
# Number of dets after get_bias_flags:  788.0  current yield  0.9162790697674419
# Number of dets with noise estimate:  788.0  current yield  0.9162790697674419
# 1760233729
# Number of dets after get_bias_flags:  788.0  current yield  0.9162790697674419
# Number of dets with noise estimate:  788.0  current yield  0.9162790697674419
# 1760236310
# Number of dets after get_bias_flags:  789.0  current yield  0.9174418604651163
# Number of dets with noise estimate:  788.0  current yield  0.9162790697674419
# 1760239879
# Number of dets after get_bias_flags:  789.0  current yield  0.9174418604651163
# Number of dets with noise estimate:  788.0  current yield  0.9162790697674419
# 1760243489
# Number of dets after get_bias_flags:  789.0  current yield  0.9174418604651163
# Number of dets with noise estimate:  789.0  current yield  0.9174418604651163
# 1760245746
# Number of dets after get_bias_flags:  790.0  current yield  0.9186046511627907
# Number of dets with noise estimate:  788.0  current yield  0.9162790697674419
# 1760249668
# Number of dets after get_bias_flags:  789.0  current yield  0.9174418604651163
# Number of dets with noise estimate:  788.0  current yield  0.9162790697674419
# 1760252724
# Number of dets after get_bias_flags:  790.0  current yield  0.9186046511627907
# Number of dets with noise estimate:  789.0  current yield  0.9174418604651163
# 1760256301
# Number of dets after get_bias_flags:  790.0  current yield  0.9186046511627907
# Number of dets with noise estimate:  789.0  current yield  0.9174418604651163
# 1760260961
# Number of dets after get_bias_flags:  788.0  current yield  0.9162790697674419
# Number of dets with noise estimate:  788.0  current yield  0.9162790697674419
# 1760263572
# Number of dets after get_bias_flags:  788.0  current yield  0.9162790697674419
# Number of dets with noise estimate:  787.0  current yield  0.9151162790697674
# 1760266461
# Number of dets after get_bias_flags:  788.0  current yield  0.9162790697674419
# Number of dets with noise estimate:  788.0  current yield  0.9162790697674419
# 1760268509
# Number of dets after get_bias_flags:  788.0  current yield  0.9162790697674419
# Number of dets with noise estimate:  787.0  current yield  0.9151162790697674
# 1760272116
# Number of dets after get_bias_flags:  788.0  current yield  0.9162790697674419
# Number of dets with noise estimate:  788.0  current yield  0.9162790697674419
# 1760276762
# Number of dets after get_bias_flags:  657.0  current yield  0.763953488372093
# Number of dets with noise estimate:  657.0  current yield  0.763953488372093
# 1760279347
# Number of dets after get_bias_flags:  788.0  current yield  0.9162790697674419
# Number of dets with noise estimate:  788.0  current yield  0.9162790697674419
# 1760282912
# Number of dets after get_bias_flags:  788.0  current yield  0.9162790697674419
# Number of dets with noise estimate:  788.0  current yield  0.9162790697674419
# 1760286512
# Number of dets after get_bias_flags:  788.0  current yield  0.9162790697674419
# Number of dets with noise estimate:  788.0  current yield  0.9162790697674419
# 1760289361
# Number of dets after get_bias_flags:  787.0  current yield  0.9151162790697674
# Number of dets with noise estimate:  787.0  current yield  0.9151162790697674
# 1760292981
# Number of dets after get_bias_flags:  787.0  current yield  0.9151162790697674
# Number of dets with noise estimate:  787.0  current yield  0.9151162790697674
# 1760295554
# Number of dets after get_bias_flags:  787.0  current yield  0.9151162790697674
# Number of dets with noise estimate:  787.0  current yield  0.9151162790697674
# 1760299119
# Number of dets after get_bias_flags:  786.0  current yield  0.913953488372093
# Number of dets with noise estimate:  786.0  current yield  0.913953488372093
# 1760303132
# Number of dets after get_bias_flags:  787.0  current yield  0.9151162790697674
# Number of dets with noise estimate:  787.0  current yield  0.9151162790697674
# 1760305619
# Number of dets after get_bias_flags:  785.0  current yield  0.9127906976744186
# Number of dets with noise estimate:  783.0  current yield  0.9104651162790698
# 1760311254
# Number of dets after get_bias_flags:  786.0  current yield  0.913953488372093
# Number of dets with noise estimate:  786.0  current yield  0.913953488372093
# 1760313271
# Number of dets after get_bias_flags:  789.0  current yield  0.9174418604651163
# Number of dets with noise estimate:  788.0  current yield  0.9162790697674419
# 1760317881
# Number of dets after get_bias_flags:  789.0  current yield  0.9174418604651163
# Number of dets with noise estimate:  788.0  current yield  0.9162790697674419
# 1760320457
# Number of dets after get_bias_flags:  791.0  current yield  0.9197674418604651
# Number of dets with noise estimate:  790.0  current yield  0.9186046511627907
# 1760324020
# Number of dets after get_bias_flags:  790.0  current yield  0.9186046511627907
# Number of dets with noise estimate:  790.0  current yield  0.9186046511627907
# 1760327622
# Number of dets after get_bias_flags:  791.0  current yield  0.9197674418604651
# Number of dets with noise estimate:  790.0  current yield  0.9186046511627907
# 1760331877
# Number of dets after get_bias_flags:  790.0  current yield  0.9186046511627907
# Number of dets with noise estimate:  789.0  current yield  0.9174418604651163
# 1760335953
# Number of dets after get_bias_flags:  790.0  current yield  0.9186046511627907
# Number of dets with noise estimate:  789.0  current yield  0.9174418604651163
# 1760339358
# Number of dets after get_bias_flags:  789.0  current yield  0.9174418604651163
# Number of dets with noise estimate:  788.0  current yield  0.9162790697674419
# 1760350212
# Number of dets after get_bias_flags:  791.0  current yield  0.9197674418604651
# Number of dets with noise estimate:  789.0  current yield  0.9174418604651163
# 1760352771
# Number of dets after get_bias_flags:  791.0  current yield  0.9197674418604651
# Number of dets with noise estimate:  791.0  current yield  0.9197674418604651
# 1760354574
# Number of dets after get_bias_flags:  791.0  current yield  0.9197674418604651
# Number of dets with noise estimate:  790.0  current yield  0.9186046511627907
# 1760358154
# Number of dets after get_bias_flags:  791.0  current yield  0.9197674418604651
# Number of dets with noise estimate:  658.0  current yield  0.7651162790697674
# 1760362804
# Number of dets after get_bias_flags:  790.0  current yield  0.9186046511627907
# Number of dets with noise estimate:  790.0  current yield  0.9186046511627907
# 1760365375
# Number of dets after get_bias_flags:  789.0  current yield  0.9174418604651163
# Number of dets with noise estimate:  503.0  current yield  0.5848837209302326
# 1760368945
# Number of dets after get_bias_flags:  789.0  current yield  0.9174418604651163
# Number of dets with noise estimate:  705.0  current yield  0.8197674418604651
# 1760372556
# Number of dets after get_bias_flags:  788.0  current yield  0.9162790697674419
# Number of dets with noise estimate:  441.99999999999994  current yield  0.513953488372093
# 1760375819
# Number of dets after get_bias_flags:  784.0  current yield  0.9116279069767442
# Number of dets with noise estimate:  784.0  current yield  0.9116279069767442
# 1760379753
# Number of dets after get_bias_flags:  785.0  current yield  0.9127906976744186
# Number of dets with noise estimate:  785.0  current yield  0.9127906976744186
# 1760385904
# Number of dets after get_bias_flags:  785.0  current yield  0.9127906976744186
# Number of dets with noise estimate:  785.0  current yield  0.9127906976744186
# 1760389778
# Number of dets after get_bias_flags:  787.0  current yield  0.9151162790697674
# Number of dets with noise estimate:  786.0  current yield  0.913953488372093
# 1760391754
# Number of dets after get_bias_flags:  787.0  current yield  0.9151162790697674
# Number of dets with noise estimate:  786.0  current yield  0.913953488372093
# 1760395472
# Number of dets after get_bias_flags:  781.0  current yield  0.9081395348837209
# Number of dets with noise estimate:  779.0  current yield  0.9058139534883721
# 1760398532
# Number of dets after get_bias_flags:  785.0  current yield  0.9127906976744186
# Number of dets with noise estimate:  785.0  current yield  0.9127906976744186
# 1760413537
# Number of dets after get_bias_flags:  781.0  current yield  0.9081395348837209
# Number of dets with noise estimate:  781.0  current yield  0.9081395348837209
# 1760414643
# Number of dets after get_bias_flags:  782.0  current yield  0.9093023255813953
# Number of dets with noise estimate:  781.0  current yield  0.9081395348837209
# 1760418111
# Number of dets after get_bias_flags:  782.0  current yield  0.9093023255813953
# Number of dets with noise estimate:  768.0  current yield  0.8930232558139535
# 1760422471
# Number of dets after get_bias_flags:  781.0  current yield  0.9081395348837209
# Number of dets with noise estimate:  781.0  current yield  0.9081395348837209
# 1760424904
# Number of dets after get_bias_flags:  778.0  current yield  0.9046511627906977
# Number of dets with noise estimate:  777.0  current yield  0.9034883720930232
# 1760429552
# Number of dets after get_bias_flags:  778.0  current yield  0.9046511627906977
# Number of dets with noise estimate:  777.0  current yield  0.9034883720930232
# 1760432126
# Number of dets after get_bias_flags:  778.0  current yield  0.9046511627906977
# Number of dets with noise estimate:  778.0  current yield  0.9046511627906977
# 1760435696
# Number of dets after get_bias_flags:  778.0  current yield  0.9046511627906977
# Number of dets with noise estimate:  777.0  current yield  0.9034883720930232
# 1760438975
# Number of dets after get_bias_flags:  783.0  current yield  0.9104651162790698
# Number of dets with noise estimate:  782.0  current yield  0.9093023255813953
# 1760441200
# Number of dets after get_bias_flags:  781.0  current yield  0.9081395348837209
# Number of dets with noise estimate:  779.0  current yield  0.9058139534883721
# 1760445841
# Number of dets after get_bias_flags:  777.0  current yield  0.9034883720930232
# Number of dets with noise estimate:  777.0  current yield  0.9034883720930232
# 1760448413
# Number of dets after get_bias_flags:  776.0  current yield  0.9023255813953488
# Number of dets with noise estimate:  775.0  current yield  0.9011627906976745
# 1760451976
# Number of dets after get_bias_flags:  778.0  current yield  0.9046511627906977
# Number of dets with noise estimate:  778.0  current yield  0.9046511627906977
# 1760455590
# Number of dets after get_bias_flags:  778.0  current yield  0.9046511627906977
# Number of dets with noise estimate:  615.0  current yield  0.7151162790697675
# 1760459186
# Number of dets after get_bias_flags:  780.0  current yield  0.9069767441860465
# Number of dets with noise estimate:  780.0  current yield  0.9069767441860465
# 1760463336
# Number of dets after get_bias_flags:  779.0  current yield  0.9058139534883721
# Number of dets with noise estimate:  779.0  current yield  0.9058139534883721
# 1760465802
# Number of dets after get_bias_flags:  772.0  current yield  0.8976744186046511
# Number of dets with noise estimate:  772.0  current yield  0.8976744186046511
# 1760469402
# Number of dets after get_bias_flags:  775.0  current yield  0.9011627906976745
# Number of dets with noise estimate:  775.0  current yield  0.9011627906976745
# 1760473001
# Number of dets after get_bias_flags:  614.0  current yield  0.713953488372093
# Number of dets with noise estimate:  614.0  current yield  0.713953488372093
# 1760475937
# Number of dets after get_bias_flags:  772.0  current yield  0.8976744186046511
# Number of dets with noise estimate:  772.0  current yield  0.8976744186046511
# 1760477904
# Number of dets after get_bias_flags:  774.0  current yield  0.9
# Number of dets with noise estimate:  758.0  current yield  0.8813953488372093
# 1760481993
# Number of dets after get_bias_flags:  777.0  current yield  0.9034883720930232
# Number of dets with noise estimate:  775.0  current yield  0.9011627906976745
# 1760484766
# Number of dets after get_bias_flags:  781.0  current yield  0.9081395348837209
# Number of dets with noise estimate:  780.0  current yield  0.9069767441860465

# %%
import matplotlib.dates as mdates
fig, ax = plt.subplots()
noise = ax.plot(times, noise_yields, label="Noise yields")
bias = ax.plot(times, bias_yields, label="Bias yields")

ax2 = ax.twinx()  
pw = ax2.plot(times, pwvs, label="PWV", c="black", alpha = 1, linestyle="--")

ax.set_xlabel("Time")
ax.set_ylabel("Yield")
ax.set_ylim(0, 1)
ax2.set_ylim(0,2)
ax2.set_ylabel("PWV")

ax.axhline(pton_df.loc[pton_df.labels==f"{band}_{ufm}", "yields"].to_numpy(), label="PTon")

plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=2))
plt.gcf().autofmt_xdate()

lns = noise+bias+pw
labs = [l.get_label() for l in lns]
ax.legend(lns, labs)
plt.title(f"Yield for UFM {ufm} band {band}")
plt.savefig(f"../plts/yields/old_yield_{ufm}_{band}.pdf", dpi=600)
plt.savefig(f"../plts/yields/old_yield_{ufm}_{band}.png", dpi=600)

plt.show()
